# %% [markdown]
# # SPLADE: Sparse Lexical and Expansion Model for First Stage Ranking

# %% [markdown]
# This notebook gives a minimal example usage of SPLADE.
#
# * In this repo, we provide weights for 2 models (in the `weights` folder)
# * See [Naver Labs Europe website](https://europe.naverlabs.com/research/machine-learning-and-optimization/splade-models/) for more up-to-date models under various settings
# * We also provide two new models via Hugging Face (https://huggingface.co/naver)
#
# | model | MRR@10 (MS MARCO dev) | recall@1000 (MS MARCO dev) | expected FLOPS | ~ avg q length | ~ avg d length |
# | --- | --- | --- | --- | --- | --- |
# | `splade_max` (**v2**) | 34.0 | 96.5 | 1.32 | 18 | 92 |
# | `distilsplade_max` (**v2**) | 36.8 | 97.9 | 3.82 | 25 | 232 |
# | `naver/splade-cocondenser-selfdistil` (**v2bis**, [HF](https://huggingface.co/naver/splade-cocondenser-selfdistil))| 37.6 | 98.4 | 2.32 | 56 | 134 |
# | `naver/splade-cocondenser-ensembledistil` (**v2bis**, [HF](https://huggingface.co/naver/splade-cocondenser-ensembledistil)) | 38.3 | 98.3  | 1.85 | 44 | 120 |

# %%
import torch
from transformers import AutoModelForMaskedLM, AutoTokenizer
from splade.models.transformer_rep import Splade

# %%
# set the dir for trained weights

##### v2
# model_type_or_dir = "weights/splade_max"
# model_type_or_dir = "weights/distilsplade_max"

### v2bis, directly download from Hugging Face
# model_type_or_dir = "naver/splade-cocondenser-selfdistil"
model_type_or_dir = "Luyu/co-condenser-marco"
model_type_or_dir = "models/ensemble_distil/checkpoint/model"
model_type_or_dir = "distilbert-base-uncased"

# %%
# loading model and tokenizer

model = Splade(model_type_or_dir, agg="max")
model.eval()
tokenizer = AutoTokenizer.from_pretrained(model_type_or_dir)
reverse_voc = {v: k for k, v in tokenizer.vocab.items()}

# %%
# example document from MS MARCO passage collection (doc_id = 8003157)

doc = "Glass and Thermal Stress. Thermal Stress is created when one area of a glass pane gets hotter than an adjacent area. If the stress is too great then the glass will crack. The stress level at which the glass will break is governed by several factors."

# %%
tokenizer
# Out:
# PreTrainedTokenizerFast(name_or_path='distilbert-base-uncased', vocab_size=30522, model_max_len=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
# now compute the document representation
with torch.no_grad():
    doc_rep = model(d_kwargs=tokenizer(doc, return_tensors="pt"))["d_rep"].squeeze()  # (sparse) doc rep in voc space, shape (30522,)

# get the number of non-zero dimensions in the rep:
col = torch.nonzero(doc_rep).squeeze().cpu().tolist()
print("number of actual dimensions: ", len(col))

# now let's inspect the bow representation:
weights = doc_rep[col].cpu().tolist()
d = {k: v for k, v in zip(col, weights)}
sorted_d = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}
bow_rep = []
for k, v in sorted_d.items():
    bow_rep.append((reverse_voc[k], round(v, 2)))
print("SPLADE BOW rep:\n", bow_rep)
# Out:
# number of actual dimensions:  9182
# SPLADE BOW rep:
#  [('glass', 3.24), ('.', 3.22), ('will', 3.22), ('at', 3.19), ('if', 3.16), ('a', 3.14), ('one', 3.14), ('when', 3.14), ('than', 3.14), ('is', 3.13), ('area', 3.13), ('crack', 3.12), ('the', 3.1), ('stress', 3.09), ('too', 3.08), ('level', 3.08), ('thermal', 3.08), ('of', 3.07), ('gets', 3.06), ('hotter', 3.04), ('several', 3.03), ('then', 3.02), ('an', 3.02), ('break', 3.01), ('adjacent', 3.0), ('created', 3.0), ('and', 2.99), ('factors', 2.98), ('by', 2.97), ('pan', 2.96), (';', 2.94), ('great', 2.92), ('which', 2.91), ('three', 2.81), ('governed', 2.81), ('high', 2.79), ('other', 2.79), ('may', 2.75), ('would', 2.74), ('many', 2.74), ('two', 2.73), ('get', 2.72), ('can', 2.72), ('##e', 2.71), ('factor', 2.71), ('generated', 2.71), ('warmer', 2.7), ('neighboring', 2.7), ('cooler', 2.7), ('hot', 2.69), ('caused', 2.68), ('determined', 2.68), ('breaking', 2.67), ('adjoining', 2.67), ('produced', 2.67), ('getting', 2.66), ('because', 2.66), ('formed', 2.66), ('window', 2.66), ('creates', 2.64), ('as', 2.64), ('four', 2.64), ('made', 2.64), ('areas', 2.64), ('create', 2.63), ('stresses', 2.63), ('various', 2.63), ('are', 2.62), ('broke', 2.62), (':', 2.61), ('levels', 2.61), ('after', 2.6), ('creating', 2.59), ('was', 2.58), ('five', 2.58), ('whenever', 2.58), ('to', 2.57), ('might', 2.57), (',', 2.56), ('where', 2.56), ('influenced', 2.56), ('section', 2.56), ('becomes', 2.56), ('hottest', 2.56), ('another', 2.55), ('got', 2.55), ('more', 2.54), ('broken', 2.54), ('fracture', 2.54), ('breaks', 2.53), ('variables', 2.53), ('shatter', 2.53), ('numerous', 2.53), ('next', 2.53), ('brighter', 2.53), ('colder', 2.52), ('region', 2.52), ('higher', 2.51), ('be', 2.51), ('heat', 2.51), ('large', 2.5), ('pressure', 2.5), ('ll', 2.5), ('surrounding', 2.5), ('controlled', 2.49), ('nearby', 2.49), ('warm', 2.49), ('##pan', 2.49), ('dependent', 2.49), ('enough', 2.49), ('glasses', 2.49), ('has', 2.49), ('that', 2.47), ('affected', 2.47), ('in', 2.47), ('any', 2.47), ('stressed', 2.46), ('different', 2.46), ('tension', 2.46), ('cool', 2.46), ('parameters', 2.46), ('induced', 2.45), ('neighbouring', 2.45), ('temperature', 2.44), ('heated', 2.44), ('larger', 2.44), ('cracked', 2.43), ('dictated', 2.43), ('under', 2.43), ('opposite', 2.42), ('following', 2.42), ('six', 2.42), ('seven', 2.42), ('outside', 2.42), ('bigger', 2.41), ('govern', 2.41), ('much', 2.41), ('multiple', 2.41), ('big', 2.4), ('some', 2.4), ('from', 2.4), ('windows', 2.4), ('being', 2.4), ('strong', 2.39), ('heating', 2.39), ('these', 2.39), ('regulated', 2.39), ('should', 2.39), ('?', 2.39), ('cracks', 2.38), ('or', 2.38), ('##glass', 2.38), ('shaped', 2.38), ('above', 2.37), ('rate', 2.37), ('edge', 2.36), ('few', 2.36), ('opposing', 2.36), ('side', 2.36), ('others', 2.36), ('defined', 2.36), ('forces', 2.36), ('on', 2.36), ('cause', 2.35), ('measured', 2.35), ('related', 2.35), ('amount', 2.35), ('governing', 2.34), ('components', 2.34), ('below', 2.34), ('goes', 2.34), ('same', 2.34), ('height', 2.34), ('mirror', 2.34), ('over', 2.33), ('characteristics', 2.33), ('cracking', 2.33), ('equivalent', 2.33), ('strain', 2.32), ('tear', 2.32), ('must', 2.32), ('during', 2.32), ('part', 2.32), ('considerations', 2.31), ('collapse', 2.31), ('comes', 2.31), ('stronger', 2.3), ('chosen', 2.3), ('feels', 2.3), ('properties', 2.3), ('effects', 2.3), ('does', 2.3), ('huge', 2.29), ('end', 2.29), ('piece', 2.29), ('burst', 2.29), ('greater', 2.29), ('starts', 2.29), ('!', 2.28), ('additional', 2.28), ('weight', 2.28), ('once', 2.28), ('influences', 2.28), ('1', 2.28), ('through', 2.28), ('describes', 2.28), ('very', 2.28), ('frame', 2.28), ('known', 2.28), ('fall', 2.27), ('control', 2.27), ('better', 2.27), ('how', 2.27), ('with', 2.27), ('extreme', 2.27), ('portion', 2.27), ('&', 2.26), ('low', 2.26), ('calculated', 2.26), ('certain', 2.26), ('wil', 2.26), ('around', 2.26), ('for', 2.26), ('similar', 2.25), ('falls', 2.25), ('mechanisms', 2.25), ('closer', 2.25), ('so', 2.25), ('condi ...

# %%
# example document from MS MARCO passage collection (doc_id = 8003157)

doc = "is a little caffeine ok during pregnancy"

# %%
# now compute the document representation
with torch.no_grad():
    doc_rep = model(d_kwargs=tokenizer(doc, return_tensors="pt"))["d_rep"].squeeze()  # (sparse) doc rep in voc space, shape (30522,)

# get the number of non-zero dimensions in the rep:
col = torch.nonzero(doc_rep).squeeze().cpu().tolist()
print("number of actual dimensions: ", len(col))

# now let's inspect the bow representation:
weights = doc_rep[col].cpu().tolist()
d = {k: v for k, v in zip(col, weights)}
sorted_d = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}
bow_rep = []
for k, v in sorted_d.items():
    bow_rep.append((reverse_voc[k], round(v, 2)))
print("SPLADE BOW rep:\n", bow_rep)
# Out:
# number of actual dimensions:  3970
# SPLADE BOW rep:
#  [('.', 2.99), ('a', 2.95), ('during', 2.92), ('little', 2.9), ('pregnancy', 2.87), ('##fe', 2.84), ('caf', 2.83), ('##ine', 2.68), ('in', 2.65), ('is', 2.49), (',', 2.46), ('pregnant', 2.43), ('bit', 2.41), ('##co', 2.38), ('slightly', 2.35), ('after', 2.32), ('when', 2.29), (';', 2.28), ('some', 2.27), ('the', 2.26), ('of', 2.26), ('mid', 2.23), ('on', 2.22), ('?', 2.22), ('good', 2.21), ('for', 2.2), ('before', 2.2), ('fe', 2.19), ('lot', 2.18), ('-', 2.18), ('while', 2.17), ('baby', 2.17), ('much', 2.16), ('early', 2.15), ('birth', 2.13), ('small', 2.13), ('##fo', 2.12), ('nice', 2.12), ('##ne', 2.11), ('just', 2.09), ('##in', 2.09), ('throughout', 2.08), ('##station', 2.08), ('and', 2.08), (')', 2.08), ('at', 2.07), ('was', 2.07), ('more', 2.06), ('following', 2.06), ('left', 2.06), ('from', 2.05), ('has', 2.04), ('##e', 2.03), ('child', 2.02), ('used', 2.02), ('big', 2.02), ('less', 2.02), ('abortion', 2.02), ('maternity', 2.01), ('##y', 2.01), ('to', 2.0), ('no', 2.0), ('!', 2.0), ('"', 1.99), ('mostly', 1.99), ('s', 1.99), ('by', 1.98), ('##ze', 1.98), ('added', 1.98), ('breast', 1.98), ('late', 1.98), ('few', 1.97), ('fetal', 1.97), ('great', 1.97), ('##le', 1.97), ('ok', 1.97), ('so', 1.97), ('hyper', 1.96), (':', 1.96), ('coffee', 1.96), ('##ing', 1.96), ('##ed', 1.95), ('##f', 1.95), ('over', 1.95), ('most', 1.95), ('p', 1.95), ('childhood', 1.94), ('mother', 1.94), ('slight', 1.94), ('one', 1.94), ('very', 1.94), ('##fa', 1.94), ('##hed', 1.93), ('g', 1.93), ('##ic', 1.93), ('be', 1.92), ('##so', 1.92), ('like', 1.91), ('mild', 1.9), ('high', 1.9), ('produced', 1.9), ('##fl', 1.9), ('...', 1.89), ('only', 1.89), ('get', 1.89), ('e', 1.88), ('newborn', 1.88), ('cl', 1.88), ('drink', 1.88), ('short', 1.88), ('not', 1.88), ('it', 1.87), ('intake', 1.87), ('female', 1.86), ('into', 1.86), ('since', 1.86), ('through', 1.86), ('##one', 1.86), ('made', 1.85), ('are', 1.85), ('choice', 1.85), ('between', 1.85), ('o', 1.85), ('released', 1.85), ('##creen', 1.85), ('##l', 1.85), ('##ly', 1.85), ('drunk', 1.85), ('with', 1.85), ('##o', 1.85), ('##ant', 1.84), ('given', 1.84), ('within', 1.84), ('##ser', 1.84), ('##fr', 1.84), ('##rine', 1.83), ('##s', 1.83), ('##tro', 1.83), ('hormone', 1.83), ('##es', 1.83), ('but', 1.83), ('an', 1.83), ('tiny', 1.83), ('something', 1.83), ('under', 1.82), ('sometimes', 1.82), ('un', 1.82), ('he', 1.82), ('##carriage', 1.82), ('can', 1.82), ('strong', 1.81), ("'", 1.81), ('toxic', 1.81), ('development', 1.81), ('sw', 1.8), ('gr', 1.8), ('her', 1.8), ('deficiency', 1.8), ('diet', 1.8), ('year', 1.8), ('childbirth', 1.79), ('se', 1.79), ('too', 1.79), ('##pa', 1.79), ('pill', 1.79), ('as', 1.79), ('gentle', 1.79), ('##ines', 1.79), ('|', 1.79), ('content', 1.78), ('i', 1.78), ('##fi', 1.78), ('least', 1.78), ('##er', 1.78), ('##her', 1.78), ('really', 1.78), ('available', 1.78), ('##ico', 1.77), ('##ses', 1.77), ('gland', 1.77), ('effective', 1.77), ('special', 1.77), ('##sal', 1.77), ('sal', 1.77), ('ph', 1.76), ('##re', 1.76), ('another', 1.76), ('present', 1.76), ('babies', 1.76), ('life', 1.75), ('##se', 1.75), ('right', 1.75), ('light', 1.75), ('fat', 1.75), ('minor', 1.75), ('air', 1.75), ('##ty', 1.75), ('gel', 1.74), ('##tic', 1.74), ('pep', 1.74), ('app', 1.74), ('marriage', 1.74), ('sleep', 1.74), ('if', 1.74), ('your', 1.73), ('##ject', 1.73), ('sc', 1.73), ('##lo', 1.73), ('this', 1.73), ('##no', 1.73), ('addict', 1.73), ('prescribed', 1.73), ('(', 1.73), ('or', 1.72), ('##and', 1.72), ('%', 1.72), ('##eno', 1.72), ('also', 1.72), ('go', 1.72), ('later', 1.72), ('pre', 1.72), ('st', 1.71), ('somewhat', 1.71), ('needed', 1.71), ('potion', 1.71), ('adult', 1.71), ('##n', 1.71), ('primary', 1.71), ('conception', 1.7), ('##af', 1.7), ('ga', 1.7), ('womb', 1.7), ('hot', 1.7), ('lots', 1.7), ('got', 1.7), ('##go', 1.7), ('premature', 1.7), ('white', 1.7), ('that', 1.7), ('##ela', 1.69), ('taken', 1.69), ('maybe', 1.69), ('##mine', 1.69), ('male', 1.69), ('##ha', 1.68), ('national', 1.68 ...

# %%
# Out:
# array([[  101,  2003,  1037,  2210, 24689,  7959,  3170,  7929,  2076,
#         10032,   102],
#        [  101,  2003,  1037,  2210, 24689,  7959,  3170,  7929,  2076,
#         10032,   102]])
