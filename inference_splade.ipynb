# %% [markdown]
# # SPLADE: Sparse Lexical and Expansion Model for First Stage Ranking

# %% [markdown]
# This notebook gives a minimal example usage of SPLADE.
#
# * In this repo, we provide weights for 2 models (in the `weights` folder)
# * See [Naver Labs Europe website](https://europe.naverlabs.com/research/machine-learning-and-optimization/splade-models/) for more up-to-date models under various settings
# * We also provide two new models via Hugging Face (https://huggingface.co/naver)
#
# | model | MRR@10 (MS MARCO dev) | recall@1000 (MS MARCO dev) | expected FLOPS | ~ avg q length | ~ avg d length |
# | --- | --- | --- | --- | --- | --- |
# | `splade_max` (**v2**) | 34.0 | 96.5 | 1.32 | 18 | 92 |
# | `distilsplade_max` (**v2**) | 36.8 | 97.9 | 3.82 | 25 | 232 |
# | `naver/splade-cocondenser-selfdistil` (**v2bis**, [HF](https://huggingface.co/naver/splade-cocondenser-selfdistil))| 37.6 | 98.4 | 2.32 | 56 | 134 |
# | `naver/splade-cocondenser-ensembledistil` (**v2bis**, [HF](https://huggingface.co/naver/splade-cocondenser-ensembledistil)) | 38.3 | 98.3  | 1.85 | 44 | 120 |

# %%
import torch
from transformers import AutoModelForMaskedLM, AutoTokenizer
from splade.models.transformer_rep import Splade, PriorSpladeV2

# %%
import multiprocessing

multiprocessing.cpu_count()
# Out:
# 40

# %%
# from transformers import AutoTokenizer, AutoModelForMaskedLM

# tokenizer = AutoTokenizer.from_pretrained("naver/splade-cocondenser-ensembledistil")

# model = AutoModelForMaskedLM.from_pretrained("naver/splade-cocondenser-ensembledistil")
# model.eval()
# reverse_voc = {v: k for k, v in tokenizer.vocab.items()}

# %%
# set the dir for trained weights

##### v2
# model_type_or_dir = "weights/splade_max"
# model_type_or_dir = "weights/distilsplade_max"

### v2bis, directly download from Hugging Face
# model_type_or_dir = "naver/splade-cocondenser-selfdistil"
model_type_or_dir = "naver/splade-cocondenser-ensembledistil"
# model_type_or_dir = "naver/efficient-splade-V-large-doc"
model_type_or_dir ="/home/taoyang/research/research_everyday/projects/DR/splade/splade/experiments/idf/checkpoint/model"

# %%
# model_type_or_dir="distilbert-base-uncased"

# %%
import pickle
idfpkl="output/idf-token.pkl"
with open(idfpkl, 'rb') as f:
    idftoken = pickle.load(f)

# %%
idftoken["too"]
# Out:
# 134309

# %%
idftoken["stress"]
# Out:
# 38178

# %%
idfpkl="output/idf-tokenid.pkl"
with open(idfpkl, 'rb') as f:
    idf = pickle.load(f)

# %%
idfTensor=torch.tensor(list(idf.values()),dtype=torch.float32)
idfTensor=torch.clip(idfTensor,10,10**6)

# %%
class PriorSplade(Splade):
    """SPLADE model
    """

    def __init__(self,idfTensor,*param,**kwparam):
        super().__init__(*param,**kwparam)
        self.idf=torch.nn.parameter.Parameter(idfTensor,requires_grad=False)
        # self.output_dim = self.transformer_rep.transformer.config.vocab_size  # output dim = vocab size = 30522 for BERT
        # assert agg in ("sum", "max")
        # self.agg = agg

    def encode(self, tokens, is_q):
        out = self.encode_(tokens, is_q)["logits"]  # shape (bs, pad_len, voc_size)
        
        if self.agg == "sum":
            return torch.sum(torch.log(1 + torch.relu(out)) * tokens["attention_mask"].unsqueeze(-1), dim=1)
        else:
            values, _ = torch.max(torch.log(1 + torch.relu(out)) * tokens["attention_mask"].unsqueeze(-1), dim=1)
            values=values/torch.log(self.idf)
            return values

# %%
class PriorSpladeV2(Splade):
    """SPLADE model
    """

    def __init__(self,idfpkl="output/idf-tokenid.pkl",*param,**kwparam):
        super().__init__(*param,**kwparam)
        idfpkl="output/idf-tokenid.pkl"
        with open(idfpkl, 'rb') as f:
            idf = pickle.load(f)
        self.idf=torch.nn.parameter.Parameter(idfTensor,requires_grad=False)
        # self.output_dim = self.transformer_rep.transformer.config.vocab_size  # output dim = vocab size = 30522 for BERT
        # assert agg in ("sum", "max")
        # self.agg = agg

    def encode(self, tokens, is_q):
        out = self.encode_(tokens, is_q)["logits"]  # shape (bs, pad_len, voc_size)
        selectedIdf=self.idf[tokens["input_ids"]]
        out=out/torch.log(selectedIdf[:,:,None])
        if self.agg == "sum":
            return torch.sum(torch.log(1 + torch.relu(out)) * tokens["attention_mask"].unsqueeze(-1), dim=1)
        else:
            values, _ = torch.max(torch.log(1 + torch.relu(out)) * tokens["attention_mask"].unsqueeze(-1), dim=1)
            values=values/torch.log(self.idf)*torch.log(self.idf.min())
            return values

# %%
# loading model and tokenizer
model = PriorSpladeV2(model_type_or_dir=model_type_or_dir, agg="max")
# model = PriorSpladeV2(idfTensor=idfTensor,model_type_or_dir=model_type_or_dir, agg="max")
model.eval()
tokenizer = AutoTokenizer.from_pretrained(model_type_or_dir)
reverse_voc = {v: k for k, v in tokenizer.vocab.items()}

# %%
# example document from MS MARCO passage collection (doc_id = 8003157)

doc = "Glass and Thermal Stress. Thermal Stress is created when one area of a glass pane gets hotter than an adjacent area. If the stress is too great then the glass will crack. The stress level at which the glass will break is governed by several factors."

# %%
# now compute the document representation
with torch.no_grad():
    doc_rep = model(d_kwargs=tokenizer(doc, return_tensors="pt"))["d_rep"].squeeze()  # (sparse) doc rep in voc space, shape (30522,)

# get the number of non-zero dimensions in the rep:
col = torch.nonzero(doc_rep).squeeze().cpu().tolist()
print("number of actual dimensions: ", len(col))

# now let's inspect the bow representation:
weights = doc_rep[col].cpu().tolist()
d = {k: v for k, v in zip(col, weights)}
sorted_d = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}
bow_rep = []
for k, v in sorted_d.items():
    bow_rep.append((reverse_voc[k], round(v, 2)))
print("SPLADE BOW rep:\n", bow_rep)
# Out:
# number of actual dimensions:  3815
# SPLADE BOW rep:
#  [('山', 0.75), ('shivered', 0.68), ('°f', 0.62), ('##ᅢ', 0.58), ('ن', 0.57), ('squinted', 0.57), ('tensed', 0.56), ('##ф', 0.54), ('wrocław', 0.52), ('##ে', 0.51), ('##ⁿ', 0.5), ('ی', 0.5), ('ز', 0.49), ('カ', 0.47), ('་', 0.46), ('##ف', 0.45), ('火', 0.44), ('##ء', 0.44), ('##ɡ', 0.43), ('и', 0.43), ('光', 0.43), ('blankly', 0.42), ('##ε', 0.42), ('°c', 0.41), ('ک', 0.4), ('##え', 0.4), ('hotter', 0.4), ('blinked', 0.4), ('shattering', 0.4), ('stresses', 0.39), ('gaped', 0.38), ('ग', 0.38), ('thermal', 0.38), ('stressed', 0.37), ('##ɲ', 0.37), ('saetan', 0.36), ('）', 0.35), ('binoculars', 0.35), ('shattered', 0.34), ('ف', 0.34), ('shatter', 0.34), ('cracking', 0.34), ('cracked', 0.33), ('shiver', 0.33), ('glasses', 0.33), ('stress', 0.33), ('tensions', 0.33), ('poznan', 0.33), ('寺', 0.33), ('crack', 0.33), ('│', 0.33), ('busted', 0.33), ('##е', 0.33), ('գ', 0.32), ('clouded', 0.32), ('gazed', 0.32), ('cracks', 0.32), ('վ', 0.31), ('koppen', 0.3), ('shivering', 0.3), ('peered', 0.3), ('smashing', 0.3), ('glass', 0.29), ('##せ', 0.29), ('ར', 0.29), ('crumbling', 0.29), ('heats', 0.29), ('##ʒ', 0.29), ('windshield', 0.28), ('declan', 0.28), ('♦', 0.28), ('ν', 0.28), ('warmer', 0.28), ('##glass', 0.28), ('fractured', 0.28), ('ง', 0.27), ('ronan', 0.27), ('∂', 0.27), ('worries', 0.27), ('glazed', 0.27), ('gdansk', 0.26), ('smashed', 0.26), ('hagen', 0.26), ('intimidated', 0.26), ('pressured', 0.26), ('pressures', 0.26), ('warmed', 0.26), ('##ggles', 0.26), ('necessitated', 0.26), ('swansea', 0.26), ('⊆', 0.26), ('reassured', 0.26), ('sash', 0.25), ('##≥', 0.25), ('caitlin', 0.25), ('##か', 0.25), ('sunglasses', 0.25), ('shards', 0.25), ('mouthed', 0.25), ('colder', 0.25), ('madeline', 0.25), ('‐', 0.25), ('dfb', 0.24), ('真', 0.24), ('jolted', 0.24), ('tension', 0.24), ('creaked', 0.24), ('fearing', 0.24), ('sipped', 0.24), ('broke', 0.24), ('optics', 0.24), ('##ᅦ', 0.24), ('tequila', 0.24), ('suspense', 0.24), ('yerevan', 0.24), ('pan', 0.24), ('breakup', 0.23), ('##ի', 0.23), ('whereupon', 0.23), ('ケ', 0.23), ('anxious', 0.23), ('hottest', 0.23), ('cooler', 0.23), ('resultant', 0.23), ('radiant', 0.23), ('infrared', 0.23), ('boiler', 0.22), ('##ₐ', 0.22), ('anxiety', 0.22), ('brooding', 0.22), ('ensued', 0.22), ('climatic', 0.22), ('boilers', 0.22), ('##ʎ', 0.22), ('telescopes', 0.22), ('intimidation', 0.22), ('splinter', 0.22), ('inducing', 0.22), ('spectacle', 0.22), ('fk', 0.22), ('worrying', 0.22), ('hartley', 0.22), ('inevitably', 0.22), ('whisky', 0.22), ('breaking', 0.22), ('ھ', 0.22), ('breaks', 0.22), ('fears', 0.22), ('created', 0.22), ('‘', 0.22), ('##≤', 0.22), ('##∂', 0.22), ('faltered', 0.21), ('heated', 0.21), ('##pressing', 0.21), ('shivers', 0.21), ('loneliness', 0.21), ('み', 0.21), ('spawned', 0.21), ('worried', 0.21), ('temper', 0.21), ('snapped', 0.21), ('meteorological', 0.21), ('smash', 0.21), ('toppled', 0.21), ('froze', 0.21), ('⟨', 0.21), ('visuals', 0.21), ('##ractive', 0.2), ('creates', 0.2), ('doom', 0.2), ('inadvertently', 0.2), ('##や', 0.2), ('break', 0.2), ('yves', 0.2), ('generating', 0.2), ('frightened', 0.2), ('unease', 0.2), ('##thermal', 0.2), ('ミ', 0.2), ('fracture', 0.2), ('外', 0.2), ('seamus', 0.2), ('heating', 0.2), ('generated', 0.2), ('tinted', 0.2), ('broken', 0.2), ('maguire', 0.2), ('cooling', 0.2), ('vickers', 0.2), ('celaena', 0.2), ('creating', 0.2), ('flutes', 0.2), ('optical', 0.2), ('arising', 0.2), ('crises', 0.2), ('crashing', 0.2), ('lucinda', 0.19), ('convection', 0.19), ('lenses', 0.19), ('cooled', 0.19), ('ニ', 0.19), ('window', 0.19), ('⟩', 0.19), ('generates', 0.19), ('waterford', 0.19), ('mirrored', 0.19), ('frames', 0.19), ('か', 0.19), ('tense', 0.19), ('threaten', 0.19), ('blinds', 0.19), ('##ungen', 0.19), ('relaxation', 0.19), ('flinched', 0.19), ('hostages', 0.19), ('factors', 0.19), ('worry', 0.19), ('macleod', 0.19), ('ج', 0.19), ('մ', 0.19), ('##dalen', 0.19), ('chilly', 0.19), ('ـ', 0.18), ('fractures', 0.18), ('windows', 0.18), ('risking', 0.18), ('creation', 0.18), ( ...

# %%
for i in bow_rep:
    if i[0]=="if":
        print(i)
        break
# Out:
# ('if', 0.05)

# %%
# example document from MS MARCO passage collection (doc_id = 8003157)

query = "Is caffeine dangerous during pregnancy?"
# query = "are you old?"
# query = "mold"

# %%
# now compute the document representation
with torch.no_grad():
    doc_rep = model(q_kwargs=tokenizer(query, return_tensors="pt"))["q_rep"].squeeze()  # (sparse) doc rep in voc space, shape (30522,)

# get the number of non-zero dimensions in the rep:
col = torch.nonzero(doc_rep).squeeze().cpu().tolist()
print("number of actual dimensions: ", len(col))

# now let's inspect the bow representation:
weights = doc_rep[col].cpu().tolist()
d = {k: v for k, v in zip(col, weights)}
sorted_d = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}
bow_rep = []
for k, v in sorted_d.items():
    bow_rep.append((reverse_voc[k], round(v, 2)))
print("SPLADE BOW rep:\n", bow_rep)
# Out:
# number of actual dimensions:  2659
# SPLADE BOW rep:
#  [('##ف', 0.93), ('##פ', 0.89), ('##ф', 0.81), ('∨', 0.72), ('squealed', 0.65), ('##ף', 0.59), ('¬', 0.58), ('##ァ', 0.55), ('cradled', 0.52), ('##ナ', 0.51), ('ィ', 0.51), ('risking', 0.46), ('sipped', 0.46), ('女', 0.44), ('clube', 0.43), ('∧', 0.4), ('risked', 0.39), ('childless', 0.38), ('maternity', 0.38), ('##な', 0.38), ('caf', 0.37), ('mommy', 0.36), ('##●', 0.36), ('dangerously', 0.35), ('childbirth', 0.35), ('treacherous', 0.34), ('dangers', 0.34), ('risky', 0.33), ('sired', 0.33), ('frightening', 0.33), ('unsafe', 0.33), ('filly', 0.33), ('##ischen', 0.33), ('momma', 0.32), ('temeraire', 0.31), ('threatens', 0.31), ('##fed', 0.31), ('natal', 0.31), ('menacing', 0.31), ('fetal', 0.31), ('drank', 0.31), ('starbucks', 0.31), ('infancy', 0.3), ('abducted', 0.3), ('lullaby', 0.3), ('sipping', 0.3), ('parenting', 0.3), ('terrifying', 0.3), ('whisky', 0.3), ('pregnancy', 0.3), ('dangerous', 0.29), ('coffee', 0.29), ('##carriage', 0.29), ('snuggled', 0.29), ('pregnant', 0.29), ('ominous', 0.29), ('danger', 0.28), ('fearing', 0.28), ('##inated', 0.28), ('hazardous', 0.28), ('womb', 0.28), ('beverages', 0.28), ('cafes', 0.27), ('##♥', 0.27), ('threaten', 0.27), ('##born', 0.27), ('##fe', 0.27), ('terrified', 0.27), ('detrimental', 0.27), ('disastrous', 0.27), ('##anger', 0.27), ('expecting', 0.27), ('barren', 0.27), ('brewing', 0.27), ('##ined', 0.27), ('maternal', 0.27), ('abortion', 0.27), ('deliveries', 0.26), ('canteen', 0.26), ('brew', 0.26), ('cesare', 0.26), ('co₂', 0.26), ('mothers', 0.26), ('scary', 0.26), ('newborn', 0.26), ('threatening', 0.26), ('harmful', 0.26), ('harmed', 0.26), ('mama', 0.25), ('##inates', 0.25), ('suicidal', 0.25), ('births', 0.25), ('fearful', 0.25), ('awaited', 0.25), ('bsc', 0.25), ('##bir', 0.25), ('rocked', 0.25), ('beverage', 0.25), ('kassel', 0.25), ('##gnan', 0.25), ('risks', 0.25), ('conceived', 0.25), ('stepmother', 0.24), ('hazards', 0.24), ('baptised', 0.24), ('babies', 0.24), ('scares', 0.24), ('amidst', 0.24), ('infant', 0.24), ('libertadores', 0.23), ('deadly', 0.23), ('##cao', 0.23), ('frightened', 0.23), ('feared', 0.23), ('damaging', 0.23), ('##station', 0.23), ('fatima', 0.23), ('cerro', 0.23), ('thumped', 0.23), ('cradle', 0.23), ('clutches', 0.22), ('cola', 0.22), ('safer', 0.22), ('##ines', 0.22), ('fathers', 0.22), ('threatened', 0.22), ('drinks', 0.22), ('conception', 0.22), ('cafe', 0.22), ('##iated', 0.22), ('disturbing', 0.22), ('infants', 0.22), ('downing', 0.22), ('cocaine', 0.22), ('worrying', 0.21), ('singleton', 0.21), ('##ine', 0.21), ('nipples', 0.21), ('parental', 0.21), ('geelong', 0.21), ('clutched', 0.21), ('whiskey', 0.21), ('##zine', 0.21), ('cocoa', 0.21), ('fertility', 0.21), ('ruining', 0.21), ('concacaf', 0.21), ('threats', 0.21), ('drink', 0.21), ('hazard', 0.21), ('##ining', 0.21), ('coca', 0.21), ('cfa', 0.21), ('##inking', 0.21), ('lobbying', 0.21), ('lethal', 0.21), ('coke', 0.21), ('brewery', 0.21), ('impending', 0.2), ('nursery', 0.2), ('fatal', 0.2), ('mummy', 0.2), ('##wife', 0.2), ('baby', 0.2), ('skimmed', 0.2), ('##amine', 0.2), ('##wives', 0.2), ('##atal', 0.2), ('immaculate', 0.2), ('amelie', 0.2), ('##inae', 0.2), ('lobby', 0.2), ('csa', 0.2), ('ufc', 0.2), ('threat', 0.2), ('toxic', 0.2), ('harm', 0.2), ('vulnerable', 0.2), ('##ntal', 0.19), ('##af', 0.19), ('nasty', 0.19), ('mated', 0.19), ('premature', 0.19), ('scared', 0.19), ('endelle', 0.19), ('loyola', 0.19), ('risk', 0.19), ('##meister', 0.19), ('imminent', 0.19), ('lucknow', 0.19), ('##nio', 0.19), ('nanny', 0.19), ('##ester', 0.19), ('milk', 0.19), ('virginity', 0.19), ('##cies', 0.19), ('adverse', 0.19), ('pepsi', 0.19), ('##sund', 0.19), ('wary', 0.19), ('congenital', 0.19), ('gulped', 0.19), ('birth', 0.18), ('beers', 0.18), ('abduction', 0.18), ('orphanage', 0.18), ('drinking', 0.18), ('prematurely', 0.18), ('reassuring', 0.18), ('horrific', 0.18), ('nesting', 0.18), ('mom', 0.18), ('##aring', 0.18), ('##ceptive', 0.18), ('##inate', 0.18), ('mother', 0.18), ('poisonous', 0.18) ...

# %%
for key in tokenizer.vocab:
    if "mold" in key:
        print(key)
# Out:
# mold
# molded
# moldova

# %%
model
# Out:
# Splade(
#   (transformer_rep): TransformerRep(
#     (transformer): BertForMaskedLM(
#       (bert): BertModel(
#         (embeddings): BertEmbeddings(
#           (word_embeddings): Embedding(30522, 768, padding_idx=0)
#           (position_embeddings): Embedding(512, 768)
#           (token_type_embeddings): Embedding(2, 768)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder): BertEncoder(
#           (layer): ModuleList(
#             (0): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (1): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (2): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (3): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (4): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (5): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (6): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (7): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (8): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (9): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (10): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (11): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#       )
#       (cls): BertOnlyMLMHead(
#         (predictions): BertLMPredictionHead(
#           (transform): BertPredictionHeadTransform(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (transform_act_fn): GELUActivation()
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (decoder): Linear(in_features=768, out_features=30522, bias=True)
#         )
#       )
#     )
#   )
# )

# %%
import os,pickle
collection_picked_file="/raid/datasets/shared/MSMARCO/collection.pickle"
if os.path.exists(collection_picked_file):
    with open(collection_picked_file, 'rb') as f:
        corpus = pickle.load(f)

# %%
corpus[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 corpus[1]
#
# KeyError: 1

# %%
len(corpus)
# Out:
# 8841823

# %%
listCorp=[]
for i in range(10**6):
    listCorp.append(corpus[str(i)])

# %%
tokenCop=tokenizer(listCorp, return_tensors="np")['input_ids']

# %%
len(tokenizer.vocab.keys())
# Out:
# 30522

# %%
tokenSet=tokenizer.vocab.values()

# %%
# tokenSet=tokenizer.vocab.values()
InverseVocab={key[1]:key[0] for ind,key in enumerate(tokenizer.vocab.items())}

# %%
numToken=len(tokenizer.vocab.keys())
idf={ind:0 for ind in range(numToken)}
idfToken={key:0 for key in tokenizer.vocab}

# %%
tokenizer.vocab["mold"]
# Out:
# 18282

# %%
token=18282
InverseVocab[token]
# Out:
# 'wakefield'

# %%
numToken=len(tokenizer.vocab.keys())
idf={ind:0 for ind in range(numToken)}
idfToken={key:0 for key in tokenizer.vocab}
moldPass=[]
moldPassU=0
for passageId,tokenSent in enumerate(tokenCop):
    SetTokenSent=set(tokenSent)
    for token in SetTokenSent:
        idf[token]+=1
        idfToken[InverseVocab[token]]+=1
        # if "mold" == InverseVocab[token]:
        #     moldPassU+=1
    # if "mold" in listCorp[passageId]:
    #     moldPass.append(listCorp[passageId])
        # print(listCorp[passageId])

# %%
corpusLen=len(corpus)

# %%
ee=list(tokenizer(listCorp[idx*batch:(idx+1)*batch], return_tensors="np")['input_ids'])

# %%
len(ee)
# Out:
# 10000

# %%
from tqdm.auto import tqdm
batch=10000
numBatch=6
tokenCop=[]
for idx in tqdm(range(0,numBatch)):
    if idx*batch>corpusLen:
        break
    tokenCop+=list(tokenizer(listCorp[idx*batch:(idx+1)*batch], return_tensors="np")['input_ids'])
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
len(tokenCop)
# Out:
# 60000

# %%
sorted(idfToken.items(), key=lambda x:x[1])
# Out:
# [('ি', 0),
#  ('も', 0),
#  ('[unused765]', 0),
#  ('disrepair', 0),
#  ('squinted', 0),
#  ('[unused51]', 0),
#  ('[unused373]', 0),
#  ('##⁻', 0),
#  ('nestor', 0),
#  ('[unused172]', 0),
#  ('[unused909]', 0),
#  ('##₃', 0),
#  ('བ', 0),
#  ('[unused164]', 0),
#  ('##জ', 0),
#  ('[unused691]', 0),
#  ('##⇒', 0),
#  ('ₛ', 0),
#  ('[unused723]', 0),
#  ('メ', 0),
#  ('ᵐ', 0),
#  ('秀', 0),
#  ('[unused317]', 0),
#  ('[unused74]', 0),
#  ('retracted', 0),
#  ('serie', 0),
#  ('spaceship', 0),
#  ('slung', 0),
#  ('whispering', 0),
#  ('##ᵏ', 0),
#  ('[unused344]', 0),
#  ('deportivo', 0),
#  ('ζ', 0),
#  ('[unused210]', 0),
#  ('##ே', 0),
#  ('[unused514]', 0),
#  ('sprawled', 0),
#  ('義', 0),
#  ('shuddered', 0),
#  ('dioceses', 0),
#  ('italianate', 0),
#  ('haynes', 0),
#  ('ᄏ', 0),
#  ('##դ', 0),
#  ('##長', 0),
#  ('##阝', 0),
#  ('[unused826]', 0),
#  ('[unused256]', 0),
#  ('[unused257]', 0),
#  ('[unused53]', 0),
#  ('##■', 0),
#  ('harmonica', 0),
#  ('[unused671]', 0),
#  ('[unused757]', 0),
#  ('##п', 0),
#  ('[unused840]', 0),
#  ('[unused927]', 0),
#  ('戦', 0),
#  ('[unused85]', 0),
#  ('grimaced', 0),
#  ('##シ', 0),
#  ('[unused441]', 0),
#  ('[unused962]', 0),
#  ('nudged', 0),
#  ('##ʋ', 0),
#  ('[unused56]', 0),
#  ('[unused710]', 0),
#  ('智', 0),
#  ('teased', 0),
#  ('⺩', 0),
#  ('littered', 0),
#  ('[unused278]', 0),
#  ('##ᴮ', 0),
#  ('##五', 0),
#  ('##貝', 0),
#  ('[unused420]', 0),
#  ('ন', 0),
#  ('##*', 0),
#  ('chapels', 0),
#  ('[unused82]', 0),
#  ('南', 0),
#  ('##中', 0),
#  ('[unused674]', 0),
#  ('チ', 0),
#  ('eastenders', 0),
#  ('##⁸', 0),
#  ('[unused27]', 0),
#  ('[unused371]', 0),
#  ('[unused675]', 0),
#  ('yugoslav', 0),
#  ('[unused130]', 0),
#  ('[unused731]', 0),
#  ('ₜ', 0),
#  ('##ら', 0),
#  ('[unused924]', 0),
#  ('tko', 0),
#  ('kurdistan', 0),
#  ('##ʌ', 0),
#  ('paralympics', 0),
#  ('省', 0),
#  ('##champ', 0),
#  ('[unused745]', 0),
#  ('[unused177]', 0),
#  ('peking', 0),
#  ('∩', 0),
#  ('⽥', 0),
#  ('[unused436]', 0),
#  ('∇', 0),
#  ('irina', 0),
#  ('habsburg', 0),
#  ('##լ', 0),
#  ('[unused224]', 0),
#  ('mbe', 0),
#  ('##⽥', 0),
#  ('glancing', 0),
#  ('##ロ', 0),
#  ('∈', 0),
#  ('森', 0),
#  ('[unused90]', 0),
#  ('leger', 0),
#  ('##秋', 0),
#  ('尚', 0),
#  ('enzo', 0),
#  ('[unused833]', 0),
#  ('[unused713]', 0),
#  ('信', 0),
#  ('غ', 0),
#  ('[unused973]', 0),
#  ('₁', 0),
#  ('faerie', 0),
#  ('宇', 0),
#  ('commended', 0),
#  ('[unused0]', 0),
#  ('[unused297]', 0),
#  ('[unused67]', 0),
#  ('##`', 0),
#  ('[unused873]', 0),
#  ('[unused180]', 0),
#  ('##ᄀ', 0),
#  ('breakaway', 0),
#  ('##谷', 0),
#  ('##щ', 0),
#  ('yearbook', 0),
#  ('[unused857]', 0),
#  ('shortlisted', 0),
#  ('[unused229]', 0),
#  ('[unused159]', 0),
#  ('„', 0),
#  ('slalom', 0),
#  ('[unused483]', 0),
#  ('carleton', 0),
#  ('မ', 0),
#  ('##上', 0),
#  ('##⁶', 0),
#  ('##đ', 0),
#  ('canucks', 0),
#  ('1753', 0),
#  ('光', 0),
#  ('[unused905]', 0),
#  ('serge', 0),
#  ('garion', 0),
#  ('[unused12]', 0),
#  ('##目', 0),
#  ('[unused480]', 0),
#  ('##ワ', 0),
#  ('malaga', 0),
#  ('rosary', 0),
#  ('tobin', 0),
#  ('ᄅ', 0),
#  ('##ɲ', 0),
#  ('argyll', 0),
#  ('giggles', 0),
#  ('[MASK]', 0),
#  ('ש', 0),
#  ('##志', 0),
#  ('##⁴', 0),
#  ('##夫', 0),
#  ('doping', 0),
#  ('[unused751]', 0),
#  ('[unused378]', 0),
#  ('##ᵢ', 0),
#  ('雄', 0),
#  ('##寺', 0),
#  ('andrey', 0),
#  ('[unused238]', 0),
#  ('##♠', 0),
#  ('anson', 0),
#  ('地', 0),
#  ('マ', 0),
#  ('##メ', 0),
#  ('দ', 0),
#  ('hitchcock', 0),
#  ('##♥', 0),
#  ('##ₛ', 0),
#  ('##ʒ', 0),
#  ('##iface', 0),
#  ('##ɒ', 0),
#  ('[unused20]', 0),
#  ('rumbled', 0),
#  ('##і', 0),
#  ('stephane', 0),
#  ('##rran', 0),
#  ('া', 0),
#  ('bangladeshi', 0),
#  ('[unused652]', 0),
#  ('[unused415]', 0),
#  ('kazan', 0),
#  ('##ত', 0),
#  ('[unused775]', 0),
#  ('##و', 0),
#  ('##ァ', 0),
#  ('º', 0),
#  ('ᴰ', 0),
#  ('downing', 0),
#  ('##博', 0),
#  ('orthogonal', 0),
#  ('##–', 0),
#  ('##ı', 0),
#  ('cheekbones', 0),
#  ('宣', 0),
#  ('氷', 0),
#  ('##ffie', 0),
#  ('##թ', 0),
#  ('₉', 0),
#  ('ல', 0),
#  ('##<', 0),
#  ('##樹', 0),
#  ('##囗', 0),
#  ('¤', 0),
#  ('mcintosh', 0),
#  ('strolled', 0),
#  ('ŋ', 0),
#  ('##神', 0),
#  ('blindly', 0),
#  ('##atz', 0),
#  ('相', 0),
#  ('ך', 0),
#  ('skopje', 0),
#  ('##α', 0),
#  ('##司', 0),
#  ('##ハ', 0),
#  ('belinda', 0),
#  ('##viere', 0),
#  ('##花', 0),
#  ('[unused597]', 0),
#  ('##ɣ', 0),
#  ('下', 0),
#  ('smackdown', 0),
#  ('musee', 0),
#  ('[unused417]', 0),
#  ('[unused265]', 0),
#  ('markham', 0),
#  ('caitlin', 0),
#  ('##ी', 0),
#  ('[unused667]', 0),
#  ('##আ', 0),
#  ('ives', 0),
#  ('[unused540]', 0),
#  ('ு', 0),
#  ('malley', 0),
#  ('[unused239]', 0),
#  ('##म', 0),
#  ('я', 0),
#  ('khyber', 0),
#  ('##gpur', 0),
#  ('ℝ', 0),
#  ('[unused58]', 0),
#  ('smashwords', 0),
#  ('[unused152]', 0),
#  ('tugging', 0),
#  ('[unused729]', 0),
#  ('[unused635]', 0),
#  ('##ᵗ', 0),
#  ('ʂ', 0),
#  ('botanic', 0),
#  ('ᵃ', 0),
#  ('[unused426]', 0),
#  ('gershwin', 0),
#  ('[unused741]', 0),
#  ('ャ', 0),
#  ('##chaft', 0),
#  ('[unused950]', 0),
#  ('##ツ', 0),
#  ('karachi', 0),
#  ('ticked', 0),
#  ('##ʻi', 0),
#  ('warden', 0),
#  ('weightlifting', 0),
#  ('[unused188]', 0),
#  ('[unused5]', 0),
#  ('##ר', 0),
#  ('##ך', 0),
#  ('[unused128]', 0),
#  ('প', 0),
#  ('vittorio', 0),
#  ('maccabi', 0),
#  ('kobayashi', 0),
#  ('1622', 0),
#  ('##∆', 0),
#  ('版', 0),
#  ('johannesburg', 0),
#  ('治', 0),
#  ('battleships', 0),
#  ('##थ', 0),
#  ('##－', 0),
#  ('[unused70]', 0),
#  ('ი', 0),
#  ('regatta', 0),
#  ('##郡', 0),
#  ('##riding', 0),
#  ('##ウ', 0),
#  ('∅', 0),
#  ('ट', 0),
#  ('magdalene', 0),
#  ('##kata', 0),
#  ('jolly', 0),
#  ('leftist', 0),
#  ('[unused311]', 0),
#  ('⊕', 0),
#  ('ы', 0),
#  ('[unused72]', 0),
#  ('⊗', 0),
#  ('bjp', 0),
#  ('“', 0),
#  ('harald', 0),
#  ('[unused530]', 0),
#  ('insistent', 0),
#  ('ま', 0),
#  ('sarcasm', 0),
#  ('[unused209]', 0),
#  ('[unused88]', 0),
#  ('grenades', 0),
#  ('lahore', 0),
#  ('[unused220]', 0),
#  ('[unused215]', 0),
#  ('##劉', 0),
#  ('recited', 0),
#  ('心', 0),
#  ('辶', 0),
#  ('מ', 0),
#  ('writhing', 0),
#  ('##ᅦ', 0),
#  ('##ե', 0),
#  ('м', 0),
#  ('moaned', 0),
#  ('##ड', 0),
#  ('ᄐ', 0),
#  ('[unused665]', 0),
#  ('ལ', 0),
#  ('cheerfully', 0),
#  ('croft', 0),
#  ('安', 0),
#  ('##比', 0),
#  ('ნ', 0),
#  ('[unused99]', 0),
#  ('[unused260]', 0),
#  ('元', 0),
#  ('##kken', 0),
#  ('canadiens', 0),
#  ('casimir', 0),
#  ('御', 0),
#  ('##belle', 0),
#  ('[unused876]', 0),
#  ('ח', 0),
#  ('ₗ', 0),
#  ('[unused390]', 0),
#  ('bradshaw', 0),
#  ('پ', 0),
#  ('[unused384]', 0),
#  ('albanian', 0),
#  ('[unused404]', 0),
#  ('đ', 0),
#  ('у', 0),
#  ('ව', 0),
#  ('interceptions', 0),
#  ('⅔', 0),
#  ('ス', 0),
#  ('ɹ', 0),
#  ('##版', 0),
#  ('[unused429]', 0),
#  ('[unused63]', 0),
#  ('ː', 0),
#  ('[unused343]', 0),
#  ('gabled', 0),
#  ('ன', 0),
#  ('##ʊ', 0),
#  ('[unused86]', 0),
#  ('yerevan', 0),
#  ('[unused55]', 0),
#  ('armagh', 0),
#  ('##⊗', 0),
#  ('##¡', 0),
#  ('ة', 0),
#  ('##ddled', 0),
#  ('昭', 0),
#  ('oskar', 0),
#  ('[unused850]', 0),
#  ('cypriot', 0),
#  ('め', 0),
#  ('[unused116]', 0),
#  ('』', 0),
#  ('javelin', 0),
#  ('gaped', 0),
#  ('interfered', 0),
#  ('ﬁ', 0),
#  ('rollins', 0),
#  ('swiped', 0),
#  ('##ბ', 0),
#  ('##с', 0),
#  ('##は', 0),
#  ('##eland', 0),
#  ('[unused106]', 0),
#  ('##★', 0),
#  ('florian', 0),
#  ('lilith', 0),
#  ('花', 0),
#  ('##jean', 0),
#  ('∧', 0),
#  ('[unused951]', 0),
#  ('ʾ', 0),
#  ('[unused627]', 0),
#  ('##宮', 0),
#  ('##bered', 0),
#  ('ג', 0),
#  ('[unused427]', 0),
#  ('[unused9]', 0),
#  ('gottingen', 0),
#  ('middlesbrough', 0),
#  ('ছ', 0),
#  ('condemning', 0),
#  ('##ˢ', 0),
#  ('saetan', 0),
#  ('gunmen', 0),
#  ('く', 0),
#  ('##dner', 0),
#  ('##ว', 0),
#  ('武', 0),
#  ('##isches', 0),
#  ('[unused562]', 0),
#  ('collingwood', 0),
#  ('##+', 0),
#  ('lola', 0),
#  ('[unused650]', 0),
#  ('[unused683]', 0),
#  ('thrusts', 0),
#  ('##~', 0),
#  ('##ふ', 0),
#  ('##√', 0),
#  ('朝', 0),
#  ('##nessy', 0),
#  ('##อ', 0),
#  ('[unused100]', 0),
#  ('dixon', 0),
#  ('[unused602]', 0),
#  ('α', 0),
#  ('hesitated', 0),
#  ('[unused663]', 0),
#  ('≤', 0),
#  ('carmichael', 0),
#  ('moffat', 0),
#  ('[unused324]', 0),
#  ('tensed', 0),
#  ('[unused948]', 0),
#  ('の', 0),
#  ('##χ', 0),
#  ('[unused336]', 0),
#  ('thwarted', 0),
#  ('commentators', 0),
#  ('[unused423]', 0),
#  ('[unused84]', 0),
#  ('##enham', 0),
#  ('[unused668]', 0),
#  ('campaigned', 0),
#  ('##འ', 0),
#  ('ᵈ', 0),
#  ('目', 0),
#  ('##§', 0),
#  ('[unused539]', 0),
#  ('walsall', 0),
#  ('minions', 0),
#  ('prayed', 0),
#  ('##yuan', 0),
#  ('wanda', 0),
#  ('[unused987]', 0),
#  ('##犬', 0),
#  ('《', 0),
#  ('[unused831]', 0),
#  ('##ள', 0),
#  ('谷', 0),
#  ('##agawa', 0),
#  ('⺼', 0),
#  ('##宿', 0),
#  ('##yin', 0),
#  ('##φ', 0),
#  ('jase', 0),
#  ('##り', 0),
#  ('dwyer', 0),
#  ('[unused29]', 0),
#  ('ο', 0),
#  ('[unused937]', 0),
#  ('##₤', 0),
#  ('chuckle', 0),
#  ('[unused517]', 0),
#  ('τ', 0),
#  ('[unused789]', 0),
#  ('[unused499]', 0),
#  ('[unused413]', 0),
#  ('[unused800]', 0),
#  ('##rsk', 0),
#  ('幸', 0),
#  ('##門', 0),
#  ('[unused138]', 0),
#  ('[unused714]', 0),
#  ('[unused16]', 0),
#  ('bsc', 0),
#  ('choked', 0),
#  ('[unused526]', 0),
#  ('##ร', 0),
#  ('[unused140]', 0),
#  ('楊', 0),
#  ('州', 0),
#  ('##rled', 0),
#  ('##氷', 0),
#  ('##₎', 0),
#  ('竹', 0),
#  ('[unused669]', 0),
#  ('[unused557]', 0),
#  ('##anov', 0),
#  ('[unused809]', 0),
#  ('##mada', 0),
#  ('##wled', 0),
#  ('[unused460]', 0),
#  ('[unused497]', 0),
#  ('[unused968]', 0),
#  ('hummed', 0),
#  ('##⊕', 0),
#  ('ব', 0),
#  ('[unused18]', 0),
#  ('[unused577]', 0),
#  ('downstairs', 0),
#  ('guadalajara', 0),
#  ('れ', 0),
#  ('[unused770]', 0),
#  ('##ვ', 0),
#  ('superstructure', 0),
#  ('[unused463]', 0),
#  ('[unused308]', 0),
#  ('beaming', 0),
#  ('radcliffe', 0),
#  ('ո', 0),
#  ('[unused877]', 0),
#  ('##ə', 0),
#  ('[unused261]', 0),
#  ('##dran', 0),
#  ('jordanian', 0),
#  ('松', 0),
#  ('ᄉ', 0),
#  ('[unused589]', 0),
#  ('─', 0),
#  ('ᆫ', 0),
#  ('leaped', 0),
#  ('bobbed', 0),
#  ('ই', 0),
#  ('blinked', 0),
#  ('נ', 0),
#  ('hannover', 0),
#  ('##〜', 0),
#  ('白', 0),
#  ('[unused985]', 0),
#  ('croix', 0),
#  ('dracula', 0),
#  ('##人', 0),
#  ('selangor', 0),
#  ('х', 0),
#  ('##ث', 0),
#  ('##ₗ', 0),
#  ('ظ', 0),
#  ('ق', 0),
#  ('##森', 0),
#  ('##や', 0),
#  ('tbilisi', 0),
#  ('[unused414]', 0),
#  ('temeraire', 0),
#  ('welterweight', 0),
#  ('ʐ', 0),
#  ('abdullah', 0),
#  ('asturias', 0),
#  ('յ', 0),
#  ('დ', 0),
#  ('horatio', 0),
#  ('vickers', 0),
#  ('や', 0),
#  ('[unused829]', 0),
#  ('quivering', 0),
#  ('##学', 0),
#  ('会', 0),
#  ('[unused129]', 0),
#  ('##、', 0),
#  ('##テ', 0),
#  ('[unused125]', 0),
#  ('pained', 0),
#  ('[unused431]', 0),
#  ('suzy', 0),
#  ('ে', 0),
#  ('rectory', 0),
#  ('##ر', 0),
#  ('curtiss', 0),
#  ('malacca', 0),
#  ('ん', 0),
#  ('godzilla', 0),
#  ('香', 0),
#  ('ruiz', 0),
#  ('frowns', 0),
#  ('行', 0),
#  ('[unused473]', 0),
#  ('[unused35]', 0),
#  ('[unused587]', 0),
#  ('attendants', 0),
#  ('[unused357]', 0),
#  ('[unused312]', 0),
#  ('##sław', 0),
#  ('բ', 0),
#  ('hopped', 0),
#  ('[unused430]', 0),
#  ('##↦', 0),
#  ('##ᅡ', 0),
#  ('##家', 0),
#  ('##立', 0),
#  ('[unused254]', 0),
#  ('wickets', 0),
#  ('##เ', 0),
#  ('[unused872]', 0),
#  ('wessex', 0),
#  ('sparkled', 0),
#  ('cocked', 0),
#  ('##ড', 0),
#  ('[unused307]', 0),
#  ('##ष', 0),
#  ('astros', 0),
#  ('●', 0),
#  ('##mania', 0),
#  ('[unused949]', 0),
#  ('[unused48]', 0),
#  ('[unused335]', 0),
#  ('ک', 0),
#  ('##美', 0),
#  ('stormed', 0),
#  ('##佐', 0),
#  ('[unused101]', 0),
#  ('##食', 0),
#  ('dietrich', 0),
#  ('##火', 0),
#  ('ᵀ', 0),
#  ('turin', 0),
#  ('routledge', 0),
#  ('reactivated', 0),
#  ('[unused505]', 0),
#  ('freyja', 0),
#  ('##ᅥ', 0),
#  ('##將', 0),
#  ('conservatoire', 0),
#  ('##岡', 0),
#  ('[unused205]', 0),
#  ('##木', 0),
#  ('##ি', 0),
#  ('shivered', 0),
#  ('sentai', 0),
#  ('ত', 0),
#  ('constituencies', 0),
#  ('bosnia', 0),
#  ('[unused147]', 0),
#  ('ezio', 0),
#  ('[unused292]', 0),
#  ('☉', 0),
#  ('土', 0),
#  ('darmstadt', 0),
#  ('##ч', 0),
#  ('₎', 0),
#  ('##е', 0),
#  ('flinders', 0),
#  ('##ব', 0),
#  ('艹', 0),
#  ('す', 0),
#  ('shriek', 0),
#  ('##ह', 0),
#  ('ள', 0),
#  ('[unused46]', 0),
#  ('[unused274]', 0),
#  ('॥', 0),
#  ('m²', 0),
#  ('##日', 0),
#  ('ₖ', 0),
#  ('##ᵖ', 0),
#  ('sudbury', 0),
#  ('##ifolia', 0),
#  ('[unused196]', 0),
#  ('##∞', 0),
#  ('[unused813]', 0),
#  ('barnet', 0),
#  ('[unused702]', 0),
#  ('wryly', 0),
#  ('reassigned', 0),
#  ('##山', 0),
#  ('##禾', 0),
#  ('²', 0),
#  ('[unused893]', 0),
#  ('ल', 0),
#  ('aleppo', 0),
#  ('##部', 0),
#  ('°c', 0),
#  ('ヒ', 0),
#  ('frowned', 0),
#  ('##พ', 0),
#  ('cockpit', 0),
#  ('##ʻ', 0),
#  ('[unused648]', 0),
#  ('[unused780]', 0),
#  ('ᵣ', 0),
#  ('[unused717]', 0),
#  ('代', 0),
#  ('##ය', 0),
#  ('##朝', 0),
#  ('比', 0),
#  ('##ν', 0),
#  ('1656', 0),
#  ('##↑', 0),
#  ('livingstone', 0),
#  ('[unused347]', 0),
#  ('##⁷', 0),
#  ('muttering', 0),
#  ('[unused651]', 0),
#  ('nairobi', 0),
#  ('##ᄏ', 0),
#  ('##ς', 0),
#  ('[unused975]', 0),
#  ('organising', 0),
#  ('whitaker', 0),
#  ('empress', 0),
#  ('[unused94]', 0),
#  ('[unused10]', 0),
#  ('ʔ', 0),
#  ('francaise', 0),
#  ('##心', 0),
#  ('##コ', 0),
#  ('б', 0),
#  ('##城', 0),
#  ('##文', 0),
#  ('##lwyn', 0),
#  ('ज', 0),
#  ('手', 0),
#  ('##州', 0),
#  ('[unused325]', 0),
#  ('和', 0),
#  ('[unused819]', 0),
#  ('[unused858]', 0),
#  ('忠', 0),
#  ('##ல', 0),
#  ('##þ', 0),
#  ('[unused223]', 0),
#  ('[unused887]', 0),
#  ('е', 0),
#  ('dragoons', 0),
#  ('##tung', 0),
#  ('minerva', 0),
#  ('ᅧ', 0),
#  ('[unused154]', 0),
#  ('##н', 0),
#  ('♥', 0),
#  ('##訁', 0),
#  ('ধ', 0),
#  ('成', 0),
#  ('[unused409]', 0),
#  ('##υ', 0),
#  ('##て', 0),
#  ('[unused744]', 0),
#  ('groans', 0),
#  ('##ᶜ', 0),
#  ('##四', 0),
#  ('##ب', 0),
#  ('##wari', 0),
#  ('ronin', 0),
#  ('##ʳ', 0),
#  ('##ße', 0),
#  ('ל', 0),
#  ('concacaf', 0),
#  ('[unused146]', 0),
#  ('##ی', 0),
#  ('さ', 0),
#  ('erskine', 0),
#  ('[unused543]', 0),
#  ('##ム', 0),
#  ('λ', 0),
#  ('[unused532]', 0),
#  ('島', 0),
#  ('〉', 0),
#  ('##в', 0),
#  ('##ס', 0),
#  ('##氵', 0),
#  ('[unused870]', 0),
#  ('[unused22]', 0),
#  ('京', 0),
#  ('[unused947]', 0),
#  ('[unused161]', 0),
#  ('ᴮ', 0),
#  ('##qvist', 0),
#  ('##代', 0),
#  ('##ان', 0),
#  ('後', 0),
#  ('[unused422]', 0),
#  ('##zhou', 0),
#  ('yokohama', 0),
#  ('ら', 0),
#  ('cheerleading', 0),
#  ('[unused604]', 0),
#  ('ᵘ', 0),
#  ('°f', 0),
#  ('##糹', 0),
#  ('ර', 0),
#  ('ט', 0),
#  ('є', 0),
#  ('त', 0),
#  ('[unused19]', 0),
#  ('##izan', 0),
#  ('##վ', 0),
#  ('##←', 0),
#  ('##א', 0),
#  ('nyu', 0),
#  ('sorbonne', 0),
#  ('ᵉ', 0),
#  ('[unused282]', 0),
#  ('[unused301]', 0),
#  ('،', 0),
#  ('÷', 0),
#  ('##镇', 0),
#  ('##武', 0),
#  ('##₅', 0),
#  ('[unused629]', 0),
#  ('forewings', 0),
#  ('フ', 0),
#  ('##止', 0),
#  ('harshly', 0),
#  ('rudy', 0),
#  ('filmfare', 0),
#  ('##ikh', 0),
#  ('georgie', 0),
#  ('##新', 0),
#  ('##土', 0),
#  ('堂', 0),
#  ('noelle', 0),
#  ('nepali', 0),
#  ('aleksandr', 0),
#  ('[unused151]', 0),
#  ('‰', 0),
#  ('##馬', 0),
#  ('த', 0),
#  ('[unused871]', 0),
#  ('##ɹ', 0),
#  ('aarhus', 0),
#  ('ᵤ', 0),
#  ('坂', 0),
#  ('西', 0),
#  ('ᄆ', 0),
#  ('##poulos', 0),
#  ('sire', 0),
#  ('リ', 0),
#  ('∂', 0),
#  ('[unused501]', 0),
#  ('[unused888]', 0),
#  ('gmina', 0),
#  ('##ク', 0),
#  ('##ッ', 0),
#  ('##γ', 0),
#  ('[unused37]', 0),
#  ('montrose', 0),
#  ('monique', 0),
#  ('[unused246]', 0),
#  ('[unused322]', 0),
#  ('itv', 0),
#  ('ড', 0),
#  ('[unused753]', 0),
#  ('gdansk', 0),
#  ('ச', 0),
#  ('##と', 0),
#  ('housemates', 0),
#  ('##yoshi', 0),
#  ('[unused621]', 0),
#  ('[unused68]', 0),
#  ('chopra', 0),
#  ('[unused141]', 0),
#  ('明', 0),
#  ('nils', 0),
#  ('थ', 0),
#  ('gottfried', 0),
#  ('[unused528]', 0),
#  ('##श', 0),
#  ('[unused43]', 0),
#  ('ヘ', 0),
#  ('viktor', 0),
#  ('[unused567]', 0),
#  ('ย', 0),
#  ('##sden', 0),
#  ('khorasan', 0),
#  ('##帝', 0),
#  ('##セ', 0),
#  ('##省', 0),
#  ('##ayton', 0),
#  ('##奈', 0),
#  ('##‐', 0),
#  ('##信', 0),
#  ('[unused333]', 0),
#  ('obeyed', 0),
#  ('春', 0),
#  ('pereira', 0),
#  ('‘', 0),
#  ('alvaro', 0),
#  ('##ছ', 0),
#  ('bellamy', 0),
#  ('[unused79]', 0),
#  ('[unused186]', 0),
#  ('##光', 0),
#  ('superliga', 0),
#  ('##skie', 0),
#  ('[unused758]', 0),
#  ('[unused230]', 0),
#  ('##間', 0),
#  ('##英', 0),
#  ('parramatta', 0),
#  ('##hly', 0),
#  ('χ', 0),
#  ('উ', 0),
#  ('[unused689]', 0),
#  ('isil', 0),
#  ('⁶', 0),
#  ('ಾ', 0),
#  ('##ต', 0),
#  ('hawthorne', 0),
#  ('zev', 0),
#  ('[unused87]', 0),
#  ('pietro', 0),
#  ('##→', 0),
#  ('##～', 0),
#  ('उ', 0),
#  ('##ɔ', 0),
#  ('coincided', 0),
#  ('nair', 0),
#  ('##北', 0),
#  ('[unused107]', 0),
#  ('##ت', 0),
#  ('[unused558]', 0),
#  ('[unused275]', 0),
#  ('##"', 0),
#  ('場', 0),
#  ('[unused36]', 0),
#  ('##ノ', 0),
#  ('##ⁱ', 0),
#  ('₇', 0),
#  ('knelt', 0),
#  ('[unused527]', 0),
#  ('shenzhen', 0),
#  ('handball', 0),
#  ('テ', 0),
#  ('[unused139]', 0),
#  ('[PAD]', 0),
#  ('##ो', 0),
#  ('##忄', 0),
#  ('bobbie', 0),
#  ('£3', 0),
#  ('[unused535]', 0),
#  ('ambushed', 0),
#  ('र', 0),
#  ('氵', 0),
#  ('##み', 0),
#  ('[unused388]', 0),
#  ('##ragan', 0),
#  ('tortricidae', 0),
#  ('[unused979]', 0),
#  ('[unused39]', 0),
#  ('[unused797]', 0),
#  ('crimean', 0),
#  ('ˢ', 0),
#  ('##и', 0),
#  ('##ক', 0),
#  ('福', 0),
#  ('##ュ', 0),
#  ('luton', 0),
#  ('glided', 0),
#  ('[unused799]', 0),
#  ('peeking', 0),
#  ('##/', 0),
#  ('[unused397]', 0),
#  ('ر', 0),
#  ('##リ', 0),
#  ('##rissa', 0),
#  ('anthropological', 0),
#  ('##イ', 0),
#  ('##आ', 0),
#  ('##מ', 0),
#  ('sniffed', 0),
#  ('[unused590]', 0),
#  ('学', 0),
#  ...]

# %%
# Is during pregnancy caffeine dangerous?

# %%
idf=np.array(list(idfToken.values()))

# %%
idf[idf>0].min()
# Out:
# 1

# %%
(idf==0).sum()
# Out:
# 2908

# %%
(idf==1).sum()
# Out:
# 35

# %%
sorted(idfToken.items(), key=lambda x:-x[1])
# Out:
# [('[SEP]', 60000),
#  ('[CLS]', 60000),
#  ('.', 58975),
#  ('the', 52594),
#  (',', 50504),
#  ('of', 44417),
#  ('and', 43502),
#  ('a', 40833),
#  ('to', 38390),
#  ('in', 36382),
#  ('is', 31998),
#  ('for', 22325),
#  ('-', 20306),
#  ('that', 17595),
#  (')', 17060),
#  ('(', 16945),
#  ('or', 16408),
#  ('on', 16330),
#  ('with', 15429),
#  ('as', 15224),
#  ('are', 15190),
#  ('it', 14810),
#  ('##s', 14246),
#  ('by', 13002),
#  (':', 12751),
#  ("'", 12622),
#  ('you', 12062),
#  ('from', 11992),
#  ('an', 11364),
#  ('be', 11339),
#  ('this', 10821),
#  ('s', 10727),
#  ('1', 10616),
#  ('at', 9957),
#  ('can', 9953),
#  ('your', 8881),
#  ('2', 8625),
#  ('have', 8181),
#  ('not', 7589),
#  ('was', 7404),
#  ('one', 6814),
#  ('which', 6624),
#  ('if', 6438),
#  ('3', 6279),
#  ('more', 6173),
#  ('has', 6160),
#  ('all', 6072),
#  ('but', 5956),
#  ('will', 5841),
#  ('when', 5713),
#  ('also', 5650),
#  ('most', 5206),
#  ('other', 5121),
#  ('##a', 5066),
#  ('they', 4896),
#  ('/', 4778),
#  ('about', 4726),
#  ('may', 4636),
#  ('##as', 4476),
#  ('there', 4436),
#  ('up', 4352),
#  ('i', 4207),
#  ('than', 4106),
#  ('4', 4082),
#  ('their', 4036),
#  ('time', 4034),
#  ('first', 4029),
#  ('new', 3853),
#  ('used', 3797),
#  ('what', 3780),
#  ('he', 3712),
#  ('some', 3674),
#  ('5', 3672),
#  ('into', 3619),
#  ('its', 3612),
#  ('use', 3571),
#  ('who', 3514),
#  ('two', 3511),
#  ('so', 3464),
#  (';', 3411),
#  ('out', 3331),
#  ('we', 3272),
#  ('these', 3187),
#  ('how', 3139),
#  ('do', 3133),
#  ('only', 3116),
#  ('over', 3105),
#  ('##ing', 3090),
#  ('after', 3076),
#  ('t', 3065),
#  ('people', 2989),
#  ('many', 2964),
#  ('his', 2960),
#  ('like', 2952),
#  ('##e', 2938),
#  ('##t', 2893),
#  ('any', 2870),
#  ('years', 2801),
#  ('been', 2786),
#  ('get', 2760),
#  ('no', 2722),
#  ('year', 2706),
#  ('between', 2677),
#  ('such', 2663),
#  ('make', 2527),
#  ('$', 2521),
#  ('10', 2480),
#  ('see', 2414),
#  ('our', 2403),
#  ('6', 2400),
#  ('states', 2399),
#  ('were', 2380),
#  ('just', 2361),
#  ('then', 2253),
#  ('each', 2245),
#  ('through', 2221),
#  ('number', 2210),
#  ('##er', 2205),
#  ('state', 2201),
#  ('called', 2189),
#  ('known', 2178),
#  ('during', 2160),
#  ('well', 2131),
#  ('world', 2123),
#  ('day', 2112),
#  ('?', 2103),
#  ('where', 2102),
#  ('per', 2092),
#  ('name', 2066),
#  ('part', 2065),
#  ('united', 2052),
#  ('because', 2048),
#  ('them', 2046),
#  ('best', 2030),
#  ('water', 2027),
#  ('##y', 2019),
#  ('while', 1998),
#  ('!', 1997),
#  ('##d', 1991),
#  ('body', 1988),
#  ('need', 1973),
#  ('before', 1972),
#  ('information', 1966),
#  ('7', 1958),
#  ('##r', 1957),
#  ('%', 1942),
#  ('should', 1927),
#  ('system', 1923),
#  ('re', 1911),
#  ('high', 1877),
#  ('8', 1860),
#  ('would', 1852),
#  ('find', 1846),
#  ('had', 1845),
#  ('made', 1831),
#  ('my', 1827),
#  ('very', 1825),
#  ('much', 1799),
#  ('both', 1788),
#  ('common', 1770),
#  ('here', 1768),
#  ('##ed', 1748),
#  ('e', 1747),
#  ('three', 1738),
#  ('long', 1724),
#  ('often', 1723),
#  ('way', 1720),
#  ('different', 1716),
#  ('now', 1711),
#  ('her', 1708),
#  ('##ly', 1708),
#  ('##n', 1704),
#  ('work', 1701),
#  ('take', 1694),
#  ('under', 1690),
#  ('&', 1679),
#  ('including', 1677),
#  ('##l', 1664),
#  ('help', 1660),
#  ('blood', 1654),
#  ('usually', 1652),
#  ('000', 1640),
#  ('same', 1631),
#  ('home', 1621),
#  ('form', 1619),
#  ('u', 1608),
#  ('type', 1601),
#  ('area', 1592),
#  ('found', 1592),
#  ('around', 1588),
#  ('american', 1566),
#  ('using', 1562),
#  ('even', 1552),
#  ('back', 1550),
#  ('right', 1524),
#  ('city', 1519),
#  ('based', 1506),
#  ('us', 1497),
#  ('life', 1496),
#  ('cause', 1491),
#  ('include', 1490),
#  ('does', 1468),
#  ('average', 1463),
#  ('place', 1459),
#  ('down', 1444),
#  ('health', 1438),
#  ('go', 1430),
#  ('however', 1427),
#  ('example', 1417),
#  ('small', 1415),
#  ('good', 1396),
#  ('##m', 1379),
#  ('com', 1377),
#  ('12', 1365),
#  ('free', 1352),
#  ('know', 1350),
#  ('top', 1344),
#  ('below', 1341),
#  ('days', 1335),
#  ('service', 1333),
#  ('15', 1324),
#  ('must', 1322),
#  ('20', 1315),
#  ('last', 1314),
#  ('being', 1301),
#  ('following', 1300),
#  ('30', 1299),
#  ('d', 1299),
#  ('end', 1293),
#  ('every', 1283),
#  ('##c', 1282),
#  ('process', 1279),
#  ('within', 1273),
#  ('important', 1263),
#  ('less', 1263),
#  ('##¦', 1261),
#  ('those', 1261),
#  ('she', 1261),
#  ('family', 1257),
#  ('b', 1240),
#  ('since', 1235),
#  ('want', 1216),
#  ('another', 1208),
#  ('located', 1205),
#  ('large', 1200),
#  ('##al', 1196),
#  ('food', 1193),
#  ('set', 1191),
#  ('off', 1189),
#  ('age', 1185),
#  ('hours', 1185),
#  ('great', 1183),
#  ('0', 1181),
#  ('person', 1178),
#  ('##i', 1172),
#  ('9', 1169),
#  ('available', 1169),
#  ('full', 1157),
#  ('##es', 1153),
#  ('means', 1148),
#  ('old', 1141),
#  ('car', 1139),
#  ('100', 1135),
#  ('cost', 1131),
#  ('##o', 1123),
#  ('term', 1119),
#  ('##x', 1117),
#  ('g', 1109),
#  ('un', 1105),
#  ('four', 1101),
#  ('according', 1092),
#  ('50', 1088),
#  ('company', 1086),
#  ('second', 1084),
#  ('##p', 1079),
#  ('north', 1074),
#  ('definition', 1074),
#  ('data', 1070),
#  ('business', 1064),
#  ('types', 1061),
#  ('change', 1061),
#  ('few', 1060),
#  ('could', 1059),
#  ('total', 1057),
#  ('m', 1053),
#  ('non', 1051),
#  ('c', 1048),
#  ('o', 1039),
#  ('low', 1036),
#  ('show', 1035),
#  ('general', 1033),
#  ('order', 1032),
#  ('medical', 1031),
#  ('amount', 1030),
#  ('red', 1026),
#  ('until', 1025),
#  ('national', 1021),
#  ('without', 1020),
#  ('side', 1015),
#  ('early', 1010),
#  ('f', 1010),
#  ('own', 1008),
#  ('##2', 1008),
#  ('level', 1004),
#  ('history', 993),
#  ('county', 990),
#  ('me', 990),
#  ('times', 988),
#  ('still', 985),
#  ('pain', 984),
#  ('##ic', 983),
#  ('symptoms', 983),
#  ('several', 983),
#  ('born', 982),
#  ('air', 977),
#  ('don', 976),
#  ('de', 975),
#  ('size', 974),
#  ('population', 972),
#  ('ve', 970),
#  ('list', 969),
#  ('care', 967),
#  ('heart', 964),
#  ('too', 964),
#  ('white', 963),
#  ('pre', 963),
#  ('range', 960),
#  ('pay', 954),
#  ('rate', 949),
#  ('st', 947),
#  ('##in', 945),
#  ('answer', 945),
#  ('power', 944),
#  ('di', 942),
#  ('start', 941),
#  ('##at', 937),
#  ('look', 935),
#  ('25', 934),
#  ('cells', 932),
#  ('main', 926),
#  ('co', 924),
#  ('group', 923),
#  ('little', 922),
#  ('english', 914),
#  ('11', 912),
#  ('check', 911),
#  ('##6', 910),
#  ('ex', 909),
#  ('[', 905),
#  ('n', 904),
#  (']', 897),
#  ('services', 897),
#  ('##h', 892),
#  ('lower', 890),
#  ('come', 885),
#  ('##0', 885),
#  ('school', 879),
#  ('##9', 874),
#  ('provide', 873),
#  ('months', 866),
#  ('local', 865),
#  ('become', 865),
#  ('south', 864),
#  ('due', 863),
#  ('word', 860),
#  ('##g', 859),
#  ('open', 855),
#  ('##on', 854),
#  ('once', 852),
#  ('p', 851),
#  ('above', 850),
#  ('causes', 849),
#  ('children', 849),
#  ('next', 848),
#  ('##4', 848),
#  ('center', 846),
#  ('major', 842),
#  ('pro', 842),
#  ('tax', 838),
#  ('##us', 836),
#  ('left', 836),
#  ('today', 835),
#  ('click', 835),
#  ('light', 835),
#  ('either', 828),
#  ('related', 825),
#  ('x', 824),
#  ('specific', 823),
#  ('program', 822),
#  ('experience', 821),
#  ('##te', 820),
#  ('short', 820),
#  ('2015', 817),
#  ('##8', 816),
#  ('##ers', 816),
#  ('america', 813),
#  ('disease', 811),
#  ('##1', 809),
#  ('meaning', 807),
#  ('men', 806),
#  ('minutes', 806),
#  ('least', 805),
#  ('standard', 805),
#  ('skin', 804),
#  ('largest', 803),
#  ('making', 803),
#  ('14', 802),
#  ('give', 801),
#  ('things', 801),
#  ('test', 798),
#  ('government', 798),
#  ('law', 797),
#  ('products', 796),
#  ('##3', 795),
#  ('sometimes', 795),
#  ('##7', 793),
#  ('although', 791),
#  ('18', 790),
#  ('line', 788),
#  ('country', 787),
#  ('current', 787),
#  ('office', 786),
#  ('percent', 785),
#  ('might', 785),
#  ('page', 784),
#  ('million', 784),
#  ('add', 779),
#  ('price', 776),
#  ('period', 775),
#  ('single', 772),
#  ('keep', 771),
#  ('public', 771),
#  ('l', 770),
#  ('point', 768),
#  ('live', 768),
#  ('given', 768),
#  ('control', 768),
#  ('real', 765),
#  ('house', 764),
#  ('president', 764),
#  ('h', 761),
#  ('learn', 760),
#  ('said', 757),
#  ('certain', 757),
#  ('along', 757),
#  ('popular', 750),
#  ('cell', 749),
#  ('human', 747),
#  ('normal', 745),
#  ('##k', 743),
#  ('24', 743),
#  ('result', 743),
#  ('16', 742),
#  ('better', 741),
#  ('later', 739),
#  ('war', 734),
#  ('support', 734),
#  ('online', 733),
#  ('five', 732),
#  ('con', 732),
#  ('am', 732),
#  ('energy', 732),
#  ('series', 732),
#  ('why', 731),
#  ('+', 729),
#  ('season', 728),
#  ('women', 725),
#  ('always', 723),
#  ('2016', 722),
#  ('act', 718),
#  ('date', 711),
#  ('##le', 711),
#  ('temperature', 709),
#  ('view', 707),
#  ('york', 707),
#  ('higher', 706),
#  ('federal', 705),
#  ('location', 704),
#  ('gas', 701),
#  ('##5', 700),
#  ('treatment', 699),
#  ('plant', 698),
#  ('case', 698),
#  ('40', 698),
#  ('caused', 696),
#  ('read', 696),
#  ('head', 695),
#  ('ad', 694),
#  ('sure', 694),
#  ('site', 692),
#  ('value', 689),
#  ('##is', 689),
#  ('black', 688),
#  ('something', 685),
#  ('cal', 684),
#  ('miles', 684),
#  ('typically', 683),
#  ('code', 681),
#  ('lot', 681),
#  ('man', 681),
#  ('west', 679),
#  ('##b', 678),
#  ('makes', 678),
#  ('2014', 678),
#  ('13', 676),
#  ('w', 673),
#  ('weight', 672),
#  ('did', 672),
#  ('having', 671),
#  ('complete', 671),
#  ('possible', 671),
#  ('comes', 667),
#  ('pressure', 667),
#  ('together', 666),
#  ('though', 664),
#  ('natural', 663),
#  ('conditions', 662),
#  ('put', 659),
#  ('generally', 659),
#  ('call', 658),
#  ('run', 658),
#  ('week', 655),
#  ('say', 650),
#  ('areas', 648),
#  ('function', 648),
#  ('similar', 648),
#  ('r', 648),
#  ('includes', 647),
#  ('##ive', 644),
#  ('think', 644),
#  ('color', 644),
#  ('60', 643),
#  ('2010', 642),
#  ('central', 641),
#  ('provides', 639),
#  ('##ness', 639),
#  ('please', 639),
#  ('love', 638),
#  ('game', 636),
#  ('##ia', 636),
#  ('##ry', 635),
#  ('contact', 635),
#  ('##or', 635),
#  ('big', 634),
#  ('month', 634),
#  ('product', 633),
#  ('condition', 633),
#  ('near', 633),
#  ('source', 632),
#  ('ll', 632),
#  ('search', 631),
#  ('account', 630),
#  ('ph', 630),
#  ('research', 629),
#  ('away', 629),
#  ('able', 628),
#  ('##f', 627),
#  ('cr', 624),
#  ('required', 623),
#  ('needs', 623),
#  ('2017', 623),
#  ('commonly', 623),
#  ('feet', 622),
#  ('others', 621),
#  ('especially', 621),
#  ('oil', 619),
#  ('##able', 619),
#  ('social', 616),
#  ('child', 615),
#  ('mean', 614),
#  ('changes', 614),
#  ('post', 612),
#  ('job', 612),
#  ('##v', 608),
#  ('en', 608),
#  ('living', 607),
#  ('across', 606),
#  ('sc', 605),
#  ('whether', 604),
#  ('##est', 604),
#  ('century', 603),
#  ('april', 603),
#  ('problems', 603),
#  ('##co', 602),
#  ('simple', 602),
#  ('music', 601),
#  ('dr', 601),
#  ('let', 600),
#  ('note', 600),
#  ('half', 600),
#  ('hot', 600),
#  ('considered', 599),
#  ('key', 598),
#  ('plan', 598),
#  ('levels', 597),
#  ('various', 595),
#  ('him', 595),
#  ('create', 595),
#  ('parts', 594),
#  ('depending', 593),
#  ('annual', 593),
#  ('doctor', 592),
#  ('17', 592),
#  ('ac', 592),
#  ('team', 591),
#  ('sub', 590),
#  ('security', 589),
#  ('heat', 589),
#  ('file', 589),
#  ('hand', 587),
#  ('going', 587),
#  ('terms', 586),
#  ('variety', 585),
#  ('surface', 584),
#  ('al', 584),
#  ('ago', 584),
#  ('quality', 583),
#  ('against', 583),
#  ('##ine', 581),
#  ('hour', 580),
#  ('among', 580),
#  ('fat', 578),
#  ('july', 576),
#  ('easy', 576),
#  ('money', 575),
#  ('california', 575),
#  ('university', 574),
#  ('actually', 572),
#  ('takes', 571),
#  ('report', 571),
#  ('earth', 570),
#  ('march', 567),
#  ('500', 567),
#  ('##tion', 566),
#  ('computer', 566),
#  ('increase', 565),
#  ('phone', 565),
#  ('enough', 563),
#  ('move', 563),
#  ('uses', 562),
#  ('hard', 562),
#  ('=', 562),
#  ('##ts', 561),
#  ('problem', 561),
#  ('six', 559),
#  ('never', 558),
#  ('web', 557),
#  ('baby', 555),
#  ('fact', 554),
#  ('individual', 553),
#  ('ne', 553),
#  ('third', 552),
#  ('##se', 552),
#  ('study', 552),
#  ('sugar', 551),
#  ('weeks', 550),
#  ('infection', 550),
#  ('market', 549),
#  ('international', 549),
#  ('january', 548),
#  ('became', 547),
#  ('try', 547),
#  ('words', 545),
#  ('development', 544),
#  ('video', 544),
#  ('21', 544),
#  ('play', 544),
#  ('special', 543),
#  ('difference', 543),
#  ('present', 543),
#  ('song', 543),
#  ('etc', 541),
#  ('star', 540),
#  ('fa', 539),
#  ('original', 538),
#  ('course', 538),
#  ('##op', 538),
#  ('language', 536),
#  ('loss', 535),
#  ('community', 534),
#  ('##ion', 533),
#  ('benefits', 533),
#  ('land', 533),
#  ('share', 533),
#  ('weather', 532),
#  ('cold', 532),
#  ('inside', 532),
#  ('throughout', 531),
#  ('risk', 531),
#  ('results', 531),
#  ('late', 530),
#  ('##id', 530),
#  ('lead', 529),
#  ('systems', 529),
#  ('members', 528),
#  ('working', 528),
#  ('access', 528),
#  ('really', 527),
#  ('night', 527),
#  ('|', 526),
#  ('##re', 526),
#  ('role', 526),
#  ('costs', 525),
#  ('forms', 524),
#  ('##ne', 524),
#  ('education', 523),
#  ('patients', 523),
#  ('class', 523),
#  ('turn', 522),
#  ('##um', 521),
#  ('apply', 521),
#  ('blue', 521),
#  ('likely', 520),
#  ('income', 520),
#  ('contains', 520),
#  ('ever', 519),
#  ('cases', 518),
#  ('almost', 518),
#  ('dry', 518),
#  ('june', 518),
#  ('k', 518),
#  ('occur', 517),
#  ('fe', 516),
#  ('written', 516),
#  ('fall', 516),
#  ('film', 515),
#  ('death', 515),
#  ('##©', 515),
#  ('credit', 513),
#  ('##rs', 513),
#  ('cut', 513),
#  ('website', 512),
#  ('management', 512),
#  ('middle', 511),
#  ('far', 510),
#  ('#', 510),
#  ('news', 509),
#  ('space', 509),
#  ('brain', 509),
#  ('effects', 509),
#  ('00', 508),
#  ('90', 508),
#  ('released', 508),
#  ('ways', 508),
#  ('done', 507),
#  ('whole', 506),
#  ('wide', 506),
#  ('insurance', 506),
#  ('created', 505),
#  ('offers', 505),
#  ('doesn', 504),
#  ('works', 504),
#  ('anti', 503),
#  ('plants', 499),
#  ('students', 498),
#  ('##u', 498),
#  ('simply', 497),
#  ('2013', 497),
#  ('region', 496),
#  ('choose', 495),
#  ('shows', 495),
#  ('says', 495),
#  ('muscle', 495),
#  ('inc', 495),
#  ('produced', 494),
#  ('network', 494),
#  ('*', 493),
#  ('built', 492),
#  ('occurs', 492),
#  ('john', 492),
#  ('##ation', 492),
#  ('material', 492),
#  ('october', 491),
#  ('book', 491),
#  ('close', 491),
#  ('won', 490),
#  ('court', 490),
#  ('base', 490),
#  ('##ma', 490),
#  ('##w', 490),
#  ('named', 490),
#  ('version', 489),
#  ('upper', 489),
#  ('##ph', 489),
#  ('tv', 488),
#  ('river', 488),
#  ('outside', 487),
#  ('physical', 487),
#  ('remove', 487),
#  ('property', 486),
#  ('80', 486),
#  ('approximately', 485),
#  ('basic', 485),
#  ('windows', 484),
#  ('section', 483),
#  ('##st', 483),
#  ('step', 482),
#  ('species', 479),
#  ('degree', 478),
#  ('story', 478),
#  ('summer', 477),
#  ('sp', 476),
#  ('production', 476),
#  ('produce', 476),
#  ('19', 475),
#  ('personal', 475),
#  ('young', 475),
#  ('industry', 474),
#  ('##nt', 474),
#  ('##en', 474),
#  ('grow', 472),
#  ('##ns', 472),
#  ('store', 472),
#  ('professional', 472),
#  ('looking', 472),
#  ('taking', 472),
#  ('numbers', 471),
#  ('##ce', 471),
#  ('select', 471),
#  ('associated', 471),
#  ('sea', 471),
#  ('foods', 470),
#  ('buy', 470),
#  ('##¢', 470),
#  ('##hy', 469),
#  ('past', 469),
#  ('23', 469),
#  ('feel', 468),
#  ('helps', 468),
#  ('again', 468),
#  ('70', 467),
#  ('pan', 467),
#  ('article', 467),
#  ('features', 467),
#  ('east', 467),
#  ('protein', 466),
#  ('2012', 465),
#  ('seen', 464),
#  ('names', 464),
#  ('green', 462),
#  ('cl', 462),
#  ('##os', 461),
#  ('august', 461),
#  ('origin', 460),
#  ('receive', 459),
#  ('eat', 458),
#  ('rec', 458),
#  ('record', 457),
#  ('growth', 457),
#  ('someone', 457),
#  ('##ies', 456),
#  ('building', 456),
#  ('addition', 455),
#  ('return', 454),
#  ('ground', 454),
#  ('##ted', 453),
#  ('department', 453),
#  ('daily', 453),
#  ('##are', 452),
#  ('follow', 452),
#  ('tissue', 451),
#  ('member', 450),
#  ('bank', 449),
#  ('currently', 448),
#  ('room', 448),
#  ('allows', 448),
#  ('22', 447),
#  ('mo', 447),
#  ('sign', 447),
#  ('sun', 446),
#  ('longer', 446),
#  ('thing', 446),
#  ('september', 445),
#  ('additional', 445),
#  ('eye', 444),
#  ('design', 444),
#  ('##ra', 444),
#  ('town', 443),
#  ('muscles', 443),
#  ('45', 441),
#  ('college', 441),
#  ('chemical', 440),
#  ('unit', 440),
#  ('cannot', 440),
#  ('diet', 438),
#  ('primary', 438),
#  ('directly', 438),
#  ('application', 437),
#  ('length', 437),
#  ('app', 436),
#  ('bit', 435),
#  ('official', 435),
#  ('countries', 435),
#  ('question', 435),
#  ('mu', 434),
#  ('ref', 434),
#  ('probably', 433),
#  ('position', 433),
#  ('##tic', 432),
#  ('square', 431),
#  ('needed', 431),
#  ('address', 431),
#  ('enter', 431),
#  ('visit', 428),
#  ('##lo', 428),
#  ('ce', 427),
#  ('degrees', 427),
#  ('designed', 427),
#  ('200', 425),
#  ('questions', 424),
#  ('taken', 424),
#  ('canada', 424),
#  ('va', 423),
#  ('effect', 423),
#  ('offer', 423),
#  ('training', 423),
#  ('island', 423),
#  ('began', 422),
#  ('field', 422),
#  ('defined', 422),
#  ('method', 421),
#  ('strong', 421),
#  ('already', 421),
#  ('##ct', 420),
#  ('acid', 420),
#  ('healthy', 420),
#  ('french', 420),
#  ('december', 419),
#  ('examples', 418),
#  ('inches', 417),
#  ('true', 417),
#  ('rest', 417),
#  ('highest', 416),
#  ('dia', 416),
#  ('got', 416),
#  ('particular', 416),
#  ('dona', 416),
#  ('legal', 415),
#  ('front', 415),
#  ('table', 413),
#  ('aa', 413),
#  ('v', 413),
#  ('upon', 413),
#  ('came', 413),
#  ('quick', 412),
#  ('kind', 412),
#  ('determine', 411),
#  ('action', 411),
#  ('cities', 411),
#  ('effective', 411),
#  ('damage', 411),
#  ('##ge', 411),
#  ('guide', 410),
#  ('surgery', 410),
#  ('art', 410),
#  ('tell', 409),
#  ('project', 409),
#  ('getting', 409),
#  ('paid', 408),
#  ('26', 408),
#  ('la', 408),
#  ('texas', 408),
#  ('##age', 408),
#  ('foot', 408),
#  ('provided', 406),
#  ('##ble', 405),
#  ('rock', 405),
#  ('require', 405),
#  ('##th', 404),
#  ('oxygen', 404),
#  ('salt', 403),
#  ('card', 403),
#  ('vary', 403),
#  ('rather', 403),
#  ('fi', 401),
#  ('king', 401),
#  ('##de', 401),
#  ('##sa', 401),
#  ('bring', 400),
#  ('financial', 400),
#  ('##ch', 400),
#  ('map', 400),
#  ('2000', 399),
#  ('fast', 399),
#  ('purpose', 399),
#  ('rates', 398),
#  ('##tes', 398),
#  ('party', 398),
#  ('##°', 397),
#  ('meat', 397),
#  ('ur', 397),
#  ('review', 397),
#  ('growing', 396),
#  ('##ie', 396),
#  ('allow', 395),
#  ('technology', 395),
#  ('europe', 394),
#  ('##ta', 394),
#  ('ca', 394),
#  ('bill', 394),
#  ...]
