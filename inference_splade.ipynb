# %% [markdown]
# # SPLADE: Sparse Lexical and Expansion Model for First Stage Ranking

# %% [markdown]
# This notebook gives a minimal example usage of SPLADE.
#
# * In this repo, we provide weights for 2 models (in the `weights` folder)
# * See [Naver Labs Europe website](https://europe.naverlabs.com/research/machine-learning-and-optimization/splade-models/) for more up-to-date models under various settings
# * We also provide two new models via Hugging Face (https://huggingface.co/naver)
#
# | model | MRR@10 (MS MARCO dev) | recall@1000 (MS MARCO dev) | expected FLOPS | ~ avg q length | ~ avg d length |
# | --- | --- | --- | --- | --- | --- |
# | `splade_max` (**v2**) | 34.0 | 96.5 | 1.32 | 18 | 92 |
# | `distilsplade_max` (**v2**) | 36.8 | 97.9 | 3.82 | 25 | 232 |
# | `naver/splade-cocondenser-selfdistil` (**v2bis**, [HF](https://huggingface.co/naver/splade-cocondenser-selfdistil))| 37.6 | 98.4 | 2.32 | 56 | 134 |
# | `naver/splade-cocondenser-ensembledistil` (**v2bis**, [HF](https://huggingface.co/naver/splade-cocondenser-ensembledistil)) | 38.3 | 98.3  | 1.85 | 44 | 120 |

# %%
import torch
from transformers import AutoModelForMaskedLM, AutoTokenizer
from splade.models.transformer_rep import Splade

# %%
from splade.models.transformer_rep import *
import pickle

# %%
# set the dir for trained weights

##### v2
# model_type_or_dir = "weights/splade_max"
# model_type_or_dir = "weights/distilsplade_max"

### v2bis, directly download from Hugging Face
# model_type_or_dir = "naver/splade-cocondenser-selfdistil"
model_type_or_dir = "Luyu/co-condenser-marco"
model_type_or_dir = "naver/splade-cocondenser-ensembledistil"
# model_type_or_dir = "distilbert-base-uncased"

# %%
with open('output/log-doc-tf-topk-10.pkl', 'rb') as f:
    doc_tf = pickle.load(f)

with open('../output/corpus-tf-log-tensor-dict.pkl', 'rb') as f:
    cortf=pickle.load( f)

# %%
# loading model and tokenizer

model = DiversitySplade(model_type_or_dir, agg="max")
model.eval()
tokenizer = AutoTokenizer.from_pretrained(model_type_or_dir)
reverse_voc = {v: k for k, v in tokenizer.vocab.items()}

# %%
# example document from MS MARCO passage collection (doc_id = 8003157)

doc = "Glass and Thermal Stress. Thermal Stress is created when one area of a glass pane gets hotter than an adjacent area. If the stress is too great then the glass will crack. The stress level at which the glass will break is governed by several factors."

# %%
tokenizer
# Out:
# PreTrainedTokenizerFast(name_or_path='naver/splade-cocondenser-ensembledistil', vocab_size=30522, model_max_len=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
# now compute the document representation
with torch.no_grad():
    doc_rep = model(d_kwargs=tokenizer(doc, return_tensors="pt"))["d_rep"].squeeze()  # (sparse) doc rep in voc space, shape (30522,)

# get the number of non-zero dimensions in the rep:
col = torch.nonzero(doc_rep).squeeze().cpu().tolist()
print("number of actual dimensions: ", len(col))

# now let's inspect the bow representation:
weights = doc_rep[col].cpu().tolist()
d = {k: v for k, v in zip(col, weights)}
sorted_d = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}
bow_rep = []
for k, v in sorted_d.items():
    bow_rep.append((reverse_voc[k], round(v, 2)))
print("SPLADE BOW rep:\n", bow_rep)
# Out:
# number of actual dimensions:  126
# SPLADE BOW rep:
#  [('stress', 2.25), ('glass', 2.23), ('thermal', 2.18), ('glasses', 1.65), ('pan', 1.62), ('heat', 1.56), ('stressed', 1.42), ('crack', 1.31), ('break', 1.12), ('cracked', 1.1), ('hot', 0.93), ('created', 0.9), ('factors', 0.81), ('broken', 0.73), ('caused', 0.71), ('too', 0.71), ('damage', 0.69), ('if', 0.68), ('hotter', 0.65), ('governed', 0.61), ('heating', 0.59), ('temperature', 0.59), ('adjacent', 0.59), ('cause', 0.58), ('effect', 0.57), ('fracture', 0.56), ('bradford', 0.55), ('strain', 0.53), ('hammer', 0.51), ('brian', 0.48), ('error', 0.47), ('windows', 0.45), ('will', 0.45), ('reaction', 0.42), ('create', 0.42), ('windshield', 0.41), ('heated', 0.41), ('factor', 0.4), ('cracking', 0.39), ('failure', 0.38), ('mechanical', 0.38), ('when', 0.38), ('formed', 0.38), ('bolt', 0.38), ('mechanism', 0.37), ('warm', 0.37), ('areas', 0.36), ('area', 0.36), ('energy', 0.34), ('disorder', 0.33), ('barry', 0.33), ('shock', 0.32), ('determined', 0.32), ('gage', 0.32), ('sash', 0.31), ('theory', 0.31), ('level', 0.31), ('resistant', 0.31), ('brake', 0.3), ('window', 0.3), ('crash', 0.3), ('hazard', 0.29), ('##ink', 0.27), ('ceramic', 0.27), ('storm', 0.25), ('problem', 0.25), ('issue', 0.24), ('impact', 0.24), ('fridge', 0.24), ('injury', 0.23), ('ross', 0.22), ('causes', 0.22), ('affect', 0.21), ('pressure', 0.21), ('fatigue', 0.21), ('leak', 0.21), ('eye', 0.2), ('frank', 0.2), ('cool', 0.2), ('might', 0.19), ('gravity', 0.18), ('ray', 0.18), ('static', 0.18), ('collapse', 0.18), ('physics', 0.18), ('wave', 0.18), ('reflection', 0.17), ('parker', 0.17), ('strike', 0.17), ('hottest', 0.17), ('burst', 0.16), ('chance', 0.16), ('burn', 0.14), ('rubbing', 0.14), ('interference', 0.14), ('bailey', 0.13), ('vibration', 0.12), ('gilbert', 0.12), ('produced', 0.12), ('rock', 0.12), ('warmer', 0.11), ('get', 0.11), ('drink', 0.11), ('fireplace', 0.11), ('ruin', 0.1), ('brittle', 0.1), ('fragment', 0.1), ('stumble', 0.09), ('formation', 0.09), ('shatter', 0.08), ('great', 0.08), ('friction', 0.08), ('flash', 0.07), ('cracks', 0.07), ('levels', 0.07), ('smash', 0.04), ('fail', 0.04), ('fra', 0.04), ('##glass', 0.03), ('variables', 0.03), ('because', 0.02), ('knock', 0.02), ('sun', 0.02), ('crush', 0.01), ('##e', 0.01), ('anger', 0.01)]

# %%
# example document from MS MARCO passage collection (doc_id = 8003157)

doc = "how much caffeine is in peach green tea"

# %%
tokken[0][argmax]
# Out:
# tensor([ 2172,  2172,  2129,  2665,  3170,  2172,  2172,  2172, 18237, 24689,
#          1999, 24689,  2003,  5572, 18237,  2129,   101,  7959,   101, 24689,
#           101,  7959,  2665,  2172,  1999,  1999,  2172,   101,   101,   101,
#         18237,  2003,  1999, 24689])

# %%
# now compute the document representation
tokken=tokenizer(doc, return_tensors="pt")['input_ids'][:,1:-1]
with torch.no_grad():
    doc_rep = model(q_kwargs=tokenizer(doc, return_tensors="pt"))["q_rep"].squeeze()  # (sparse) doc rep in voc space, shape (30522,)
    argmax = model(q_kwargs=tokenizer(doc, return_tensors="pt"))["argmax"].squeeze() 
# get the number of non-zero dimensions in the rep:
col = torch.nonzero(doc_rep).squeeze().cpu().tolist()
print("number of actual dimensions: ", len(col))

# now let's inspect the bow representation:
weights = doc_rep[col].cpu().tolist()
argmax = argmax[col].cpu().tolist()
source=tokken[0][argmax].cpu().tolist()
d = {k: (v,j) for k, v,j in zip(col, weights,source)}
sorted_d = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}
bow_rep = []
for k, v in sorted_d.items():
    bow_rep.append((reverse_voc[k],reverse_voc[v[1]], round(v[0], 2)))
print("SPLADE BOW rep:\n", bow_rep)
# Out:
# number of actual dimensions:  29
# SPLADE BOW rep:
#  [('peach', 'peach', 2.42), ('tea', 'tea', 2.15), ('caf', 'caf', 1.7), ('green', 'green', 1.63), ('##fe', '##fe', 1.49), ('georgia', 'peach', 1.48), ('##ine', '##ine', 1.24), ('##ories', 'is', 1.21), ('weight', 'much', 1.1), ('content', 'in', 1.07), ('mg', 'much', 0.88), ('total', 'how', 0.87), ('much', 'much', 0.86), ('amount', 'much', 0.83), ('coffee', 'caf', 0.82), ('drink', 'caf', 0.54), ('cal', 'caf', 0.43), ('smooth', 'peach', 0.42), ('dose', 'much', 0.39), ('fruit', 'in', 0.35), ('%', 'much', 0.29), ('max', 'much', 0.29), ('herb', 'in', 0.27), ('##lor', '##fe', 0.2), ('contain', 'is', 0.19), ('greene', 'green', 0.16), ('rating', 'how', 0.15), ('ingredient', 'in', 0.13), ('pepper', 'in', 0.01)]

# %%
tokken=tokken[0]
for t in tokken:
    print(reverse_voc[t])
# Out:
# [CLS]
# how
# much
# caf
# ##fe
# ##ine
# is
# in
# peach
# green
# tea
# [SEP]

# %%
reverse_voc
# Out:
# {20012: 'glover',
#  21369: '##asi',
#  19714: '640',
#  10706: 'wrestler',
#  14305: 'extensions',
#  13173: 'kara',
#  441: '[unused436]',
#  7496: 'ease',
#  25746: '##52',
#  12956: '##ante',
#  4541: 'explained',
#  14791: 'jasper',
#  20134: 'longitudinal',
#  22066: 'linden',
#  26225: 'arden',
#  5055: 'birds',
#  4591: 'qualified',
#  13526: 'skeleton',
#  18193: 'mandy',
#  20230: 'putnam',
#  24594: '##29',
#  25349: 'draught',
#  6193: '1890',
#  6820: '##ru',
#  19577: 'oxidation',
#  1552: '₅',
#  7682: 'bearing',
#  15043: 'ached',
#  27628: 'carousel',
#  16177: '##ν',
#  24225: '##edge',
#  14474: 'gaza',
#  328: '[unused323]',
#  17845: 'byrd',
#  17876: 'elongated',
#  291: '[unused286]',
#  862: '[unused857]',
#  182: '[unused177]',
#  14009: 'observers',
#  23753: 'greenish',
#  25469: '##dity',
#  26004: 'valuation',
#  28625: 'astro',
#  9773: 'nominee',
#  11524: 'nsw',
#  9067: '##mal',
#  27798: '##hiti',
#  16326: 'absorption',
#  19530: 'acquisitions',
#  13496: 'teens',
#  16458: '##cross',
#  25756: 'hammered',
#  27953: '##anal',
#  4654: 'ex',
#  23614: 'pediatric',
#  10251: 'acclaimed',
#  22035: 'quo',
#  27497: '1638',
#  28183: '##grating',
#  8702: 'attractive',
#  25272: 'nouveau',
#  6181: 'knee',
#  1115: 'ɛ',
#  11781: 'erin',
#  27304: 'drip',
#  13335: 'resisted',
#  20669: 'dharma',
#  28938: 'messengers',
#  26833: '1728',
#  6857: 'rocky',
#  17939: 'welch',
#  18776: 'blackwell',
#  25093: 'jens',
#  9054: 'guild',
#  1217: 'ћ',
#  4840: 'fresh',
#  25253: '##esian',
#  8831: 'ports',
#  1946: '街',
#  6536: 'pole',
#  15619: 'vacancy',
#  22108: 'siemens',
#  5429: 'shifted',
#  9355: '##ising',
#  2087: 'most',
#  16259: '##rator',
#  19392: '##tooth',
#  29809: '##צ',
#  12919: 'strengthen',
#  14648: 'staggered',
#  4306: 'crowd',
#  21058: 'ono',
#  25226: '##lino',
#  8638: 'fence',
#  15581: 'adapt',
#  11387: '##20',
#  19322: 'shropshire',
#  9403: 'headquartered',
#  22123: '##yt',
#  25813: 'watering',
#  2659: 'low',
#  26423: '1724',
#  12358: 'strangers',
#  371: '[unused366]',
#  24522: '1747',
#  20263: '540',
#  1678: 'み',
#  29824: '##س',
#  7014: 'beth',
#  17807: 'luton',
#  25153: '##bang',
#  6777: '##ev',
#  14534: '£1',
#  29460: 'decorate',
#  6324: 'defeating',
#  16079: 'verge',
#  30138: '##⊆',
#  3596: 'forms',
#  15281: 'clips',
#  13313: 'fortified',
#  3647: 'safe',
#  10867: '##rm',
#  27250: 'tangent',
#  6831: 'civilian',
#  6045: 'hat',
#  29600: 'collarbone',
#  6263: 'minimum',
#  21511: '##oof',
#  10291: 'belgrade',
#  28448: 'eruptions',
#  1625: '♥',
#  4218: 'beneath',
#  3644: 'jewish',
#  15856: 'pumps',
#  14105: 'oversaw',
#  9488: '##rio',
#  20155: 'quantitative',
#  26277: 'ceasefire',
#  20844: '##lena',
#  2524: 'hard',
#  10609: '##ben',
#  21281: '##phy',
#  14532: 'wrath',
#  15946: 'induction',
#  11078: 'confederation',
#  15385: 'lick',
#  28664: 'probing',
#  28282: '##tama',
#  16288: '##coe',
#  18866: '##watch',
#  20862: 'scarlett',
#  25035: 'yourselves',
#  17800: 'illegally',
#  23121: 'wexford',
#  18988: 'inspiring',
#  680: '[unused675]',
#  22153: '##lini',
#  5317: 'coal',
#  1328: 'प',
#  29889: '##ক',
#  17136: 'jain',
#  22472: 'indigo',
#  23637: 'insulted',
#  3525: 'subsequently',
#  23123: 'falsely',
#  2237: 'town',
#  24478: 'refurbishment',
#  29451: '##gano',
#  18781: 'vase',
#  4623: 'poetry',
#  10275: 'filipino',
#  4944: 'architect',
#  7627: 'jesse',
#  28048: '402',
#  8077: 'extensively',
#  2830: 'forward',
#  13693: 'confluence',
#  19663: '##yuki',
#  16511: 'resorts',
#  17065: 'uzbekistan',
#  29063: 'vikram',
#  11969: 'scratch',
#  14135: 'griffith',
#  8488: 'chaos',
#  30005: '##ᄒ',
#  5028: 'touched',
#  4240: 'serves',
#  12693: '##stan',
#  3659: 'spread',
#  15175: 'unwilling',
#  29726: '##κ',
#  11932: 'sacramento',
#  19774: 'aristocratic',
#  4786: 'causing',
#  19592: 'protestants',
#  29228: 'cambrian',
#  6539: '1894',
#  8759: 'founders',
#  11620: 'rita',
#  13875: 'reilly',
#  29859: '##त',
#  20485: 'clarified',
#  8993: 'exploration',
#  27274: 'vantage',
#  18315: 'vc',
#  53: '[unused52]',
#  6768: 'delhi',
#  7500: 'farmer',
#  20973: 'cemeteries',
#  21467: 'awarding',
#  3829: 'kitchen',
#  16225: 'mckay',
#  19991: '##hong',
#  1817: '学',
#  129: '[unused124]',
#  21990: 'bargaining',
#  17107: 'morse',
#  24589: '##dened',
#  2009: 'it',
#  13380: '##yar',
#  20971: 'quartz',
#  9482: 'richardson',
#  24034: 'oblivion',
#  25526: '##bm',
#  21480: 'oyster',
#  29085: 'augusto',
#  27309: 'madeira',
#  13202: 'licensing',
#  1299: 'ى',
#  13628: 'grandchildren',
#  7124: 'trinity',
#  22570: 'expressive',
#  20236: '##sier',
#  10575: 'locals',
#  15674: 'linebacker',
#  27148: 'darkly',
#  15343: '##bbling',
#  13030: 'lotus',
#  26067: '##tang',
#  22246: 'cristina',
#  25325: 'esq',
#  26196: 'maguire',
#  27689: '1721',
#  29705: '##ʔ',
#  7893: 'verse',
#  25971: 'detectors',
#  17383: 'boarded',
#  19993: '##wife',
#  8183: 'jo',
#  1153: 'ˣ',
#  10898: 'speeds',
#  21809: '1745',
#  22839: 'clockwise',
#  5651: 'returns',
#  14120: 'responding',
#  9636: 'damned',
#  5760: 'pure',
#  27706: 'fitz',
#  3988: 'initial',
#  29887: '##এ',
#  11614: '##old',
#  23551: 'aimee',
#  15363: 'desktop',
#  1399: 'ை',
#  18844: 'quaker',
#  24772: '##shima',
#  12139: 'alignment',
#  16776: 'wee',
#  19360: 'bethlehem',
#  8718: '##din',
#  14922: 'grunted',
#  11001: '##lled',
#  12302: 'confined',
#  25072: 'wiener',
#  2608: 'arms',
#  16735: 'traps',
#  5388: '58',
#  4890: '##ny',
#  195: '[unused190]',
#  22732: 'patti',
#  5498: '##ini',
#  28213: 'handler',
#  1423: 'เ',
#  10704: 'roberto',
#  11751: '##plane',
#  7019: 'erected',
#  25001: 'fluttering',
#  9825: '##hus',
#  15571: 'unfair',
#  4484: 'confirmed',
#  30322: '##和',
#  7045: 'assets',
#  11107: 'initiatives',
#  21014: 'cinematic',
#  15127: 'descending',
#  7031: 'roberts',
#  1011: '-',
#  18554: 'dye',
#  7814: 'aspect',
#  376: '[unused371]',
#  16237: 'wilkinson',
#  27046: 'thru',
#  11626: 'trafficking',
#  13253: 'baha',
#  16262: 'antony',
#  26186: 'judgments',
#  18364: 'assassins',
#  8608: 'tactical',
#  22486: '##ivism',
#  787: '[unused782]',
#  2280: 'former',
#  25157: 'chet',
#  8062: 'petersburg',
#  14680: '##bilities',
#  27409: 'pedersen',
#  15052: 'okinawa',
#  25061: 'gurney',
#  24779: 'rocker',
#  6577: 'participation',
#  7506: 'subsidiary',
#  25283: 'tran',
#  1049: 'm',
#  1594: '∆',
#  7671: 'swung',
#  15916: '##ug',
#  2627: 'past',
#  12374: 'incorporates',
#  23530: 'raiding',
#  7927: 'favour',
#  6734: 'portland',
#  27980: 'trolls',
#  16888: 'absorb',
#  19299: 'pitches',
#  12360: 'consortium',
#  29285: 'astoria',
#  1391: 'ர',
#  24242: '##istle',
#  8742: 'sensation',
#  7326: '1876',
#  8517: '1858',
#  15835: 'arguably',
#  3609: 'color',
#  2131: 'get',
#  17162: 'blazing',
#  26389: 'flavors',
#  2552: 'act',
#  27684: '##bbon',
#  1459: 'ᄆ',
#  27048: 'loaf',
#  28170: 'dissemination',
#  7131: '1882',
#  16682: 'contemporaries',
#  7973: '1850',
#  11203: 'harvest',
#  11365: '##vis',
#  21124: 'nairobi',
#  23248: '##ropolis',
#  27913: 'mahal',
#  2863: '##ma',
#  27176: '##urgent',
#  1413: 'น',
#  26387: '##monium',
#  3593: '##id',
#  27582: '1732',
#  28811: 'subterranean',
#  14814: 'judiciary',
#  1374: 'শ',
#  4524: 'bag',
#  30309: '##十',
#  233: '[unused228]',
#  1616: '│',
#  12489: 'kidding',
#  25378: '##ports',
#  436: '[unused431]',
#  1007: ')',
#  17045: 'wiltshire',
#  20239: 'guido',
#  23869: 'steamship',
#  25169: 'scaling',
#  738: '[unused733]',
#  21487: 'barons',
#  13647: 'asserted',
#  24395: '##ergy',
#  17680: 'outlook',
#  120: '[unused115]',
#  2309: 'single',
#  10285: '##ees',
#  22025: '##38',
#  27035: '##bread',
#  29230: 'verve',
#  28120: '##mut',
#  4583: '55',
#  16010: 'unpleasant',
#  12924: 'judith',
#  8031: 'binding',
#  26808: 'horned',
#  29459: '##orro',
#  148: '[unused143]',
#  24246: 'rooney',
#  29104: 'inaccessible',
#  22646: '##евич',
#  17042: 'weigh',
#  27314: 'valor',
#  19985: 'sighted',
#  2905: 'sister',
#  2007: 'with',
#  21056: 'wreckage',
#  13434: 'viral',
#  13532: 'subjected',
#  5637: 'gay',
#  7873: 'leeds',
#  10780: 'badge',
#  18748: 'angered',
#  20659: 'stalled',
#  23936: 'replacements',
#  3091: 'length',
#  15497: 'awaiting',
#  15681: 'forge',
#  10278: '##lam',
#  16241: 'evenings',
#  30147: '##★',
#  4013: 'pro',
#  13533: 'orchestral',
#  5432: 'warning',
#  13755: 'darkened',
#  28534: '##rzy',
#  22695: 'mariano',
#  590: '[unused585]',
#  22694: '##forms',
#  27099: 'triggers',
#  16492: 'spinal',
#  3996: 'columbia',
#  15546: 'honoured',
#  572: '[unused567]',
#  14237: 'wanderers',
#  11480: 'anxious',
#  20103: 'musicals',
#  29517: 'florian',
#  18448: 'anarchist',
#  27680: 'ebony',
#  20944: 'roe',
#  313: '[unused308]',
#  2490: 'support',
#  8235: 'brilliant',
#  17672: 'poisoned',
#  5041: 'broad',
#  12446: 'offs',
#  23167: 'achilles',
#  20393: 'neutron',
#  16898: '##xie',
#  21908: 'pulmonary',
#  4692: 'attempted',
#  3718: 'removed',
#  14514: 'goodman',
#  3503: 'matches',
#  6766: 'keith',
#  12951: '50th',
#  25190: '##dberg',
#  12031: '##fy',
#  23462: 'sinks',
#  11167: 'screenwriter',
#  17035: 'hurricanes',
#  5202: 'dragon',
#  27934: 'dahl',
#  6647: 'marcus',
#  1805: '堂',
#  6983: 'finnish',
#  14945: '##hd',
#  20690: 'adjutant',
#  17759: '##sity',
#  2387: 'saw',
#  25763: 'oneself',
#  19415: 'graceful',
#  22843: 'banged',
#  17518: 'lindsey',
#  7858: 'youtube',
#  29468: 'gills',
#  20765: 'philipp',
#  8084: 'struggling',
#  18983: 'seville',
#  8441: 'freight',
#  28087: 'imperialism',
#  9376: 'aggressive',
#  3671: 'normal',
#  6645: 'borders',
#  261: '[unused256]',
#  911: '[unused906]',
#  8101: 'shakespeare',
#  9292: 'fork',
#  20051: '##lat',
#  6608: 'signing',
#  26927: 'pri',
#  26346: 'rags',
#  29200: 'substitutes',
#  25496: 'aromatic',
#  9790: 'sue',
#  23717: 'hooper',
#  4734: 'rooms',
#  18430: 'warwickshire',
#  20490: 'pausing',
#  27891: 'utilization',
#  28039: '##aday',
#  30130: '##∨',
#  27270: 'messina',
#  9444: 'whoever',
#  17234: 'wills',
#  22683: 'tinged',
#  27915: '##pins',
#  23739: 'lukas',
#  325: '[unused320]',
#  3777: '1961',
#  704: '[unused699]',
#  6976: 'frequent',
#  8527: 'bryan',
#  15410: 'monitors',
#  19171: 'swirled',
#  30328: '##地',
#  11783: '##hard',
#  3138: 'takes',
#  7562: 'tours',
#  7030: 'm²',
#  15590: '##atus',
#  16668: 'terribly',
#  28585: 'mergers',
#  5577: 'describes',
#  5625: 'begun',
#  26968: 'nostalgia',
#  4850: 'angel',
#  26093: 'euroleague',
#  12637: 'advantages',
#  9906: 'lately',
#  1228: 'հ',
#  4318: 'dry',
#  7545: 'brings',
#  14521: 'lexington',
#  7502: 'grows',
#  21954: 'pursed',
#  27207: 'fusiliers',
#  23504: 'ominous',
#  23980: '316',
#  30418: '##民',
#  5773: 'louisiana',
#  16781: '##piration',
#  6990: 'stuart',
#  7505: 'sur',
#  3035: 'queen',
#  17857: 'attackers',
#  20314: 'towering',
#  22366: 'rockies',
#  23258: 'jozef',
#  14265: 'corporal',
#  5734: 'aviation',
#  17639: 'conner',
#  4658: 'cool',
#  24980: 'fragrance',
#  17580: '##eis',
#  15527: 'mutant',
#  11122: 'cart',
#  28888: 'custer',
#  4987: 'attached',
#  14415: 'mayo',
#  1268: '،',
#  15216: 'bamboo',
#  16800: 'whitish',
#  5119: 'clock',
#  20251: 'sato',
#  20374: 'elector',
#  27946: 'zimmerman',
#  3761: 'politician',
#  18146: 'psychiatrist',
#  21344: 'toad',
#  21375: 'galactic',
#  28242: '##rgeon',
#  4705: 'kg',
#  6785: 'glasgow',
#  28796: 'seton',
#  25423: 'ua',
#  15901: 'extracted',
#  29174: 'containment',
#  8602: '##stein',
#  11: '[unused10]',
#  4424: 'sexual',
#  9057: '##zar',
#  14318: 'pagan',
#  22987: '##cis',
#  2139: 'de',
#  13626: '##dr',
#  2964: '##ism',
#  587: '[unused582]',
#  674: '[unused669]',
#  5698: 'demon',
#  8994: 'amber',
#  30428: '##海',
#  20548: 'garlic',
#  22560: 'solitude',
#  21802: 'periodical',
#  9804: 'choices',
#  17323: 'guinness',
#  18694: 'hitter',
#  29419: '##zcz',
#  8307: 'somebody',
#  2607: 'course',
#  28520: 'hoax',
#  21682: '##aling',
#  1410: 'ง',
#  413: '[unused408]',
#  12617: '##gas',
#  17764: 'jackets',
#  19857: 'flu',
#  27740: '##wyl',
#  17716: 'moose',
#  24079: '##amy',
#  2305: 'night',
#  3513: 'rules',
#  27212: 'earrings',
#  20037: 'inverted',
#  6748: 'deeper',
#  8937: 'buddy',
#  11378: 'pottery',
#  25769: 'breached',
#  2452: 'cup',
#  2611: 'girl',
#  22244: '##saurus',
#  24344: '##meyer',
#  9282: 'suburban',
#  10495: 'consolidated',
#  25144: 'commandos',
#  12960: 'titular',
#  8641: 'bags',
#  13452: 'trout',
#  9964: 'petition',
#  12197: 'watches',
#  26998: 'fukuoka',
#  4621: 'effective',
#  26950: '##parts',
#  2612: 'instead',
#  30119: '##⇒',
#  15323: 'motions',
#  25575: '##quay',
#  4220: 'yard',
#  14726: 'stunning',
#  15106: 'convenience',
#  16028: 'senegal',
#  22770: 'jae',
#  23178: 'yank',
#  15524: 'fundraising',
#  2779: 'average',
#  8889: '##00',
#  19193: 'nj',
#  3973: '##ally',
#  7749: 'examination',
#  18733: 'croix',
#  22935: 'cardiovascular',
#  26790: 'privateer',
#  16487: 'restoring',
#  12264: 'nuts',
#  16312: 'tempted',
#  18572: 'gaston',
#  24690: '415',
#  26103: 'courageous',
#  807: '[unused802]',
#  4893: 'artillery',
#  11381: 'obtaining',
#  13893: 'rejection',
#  739: '[unused734]',
#  22109: 'stairwell',
#  25389: '##nad',
#  17225: 'electromagnetic',
#  14778: '##rit',
#  24237: '##ump',
#  12150: 'wrists',
#  10598: 'walt',
#  16004: 'appealing',
#  976: '[unused971]',
#  17165: 'hutchinson',
#  8918: '##uous',
#  13865: 'wolfgang',
#  9031: '##ification',
#  4744: 'truck',
#  7239: 'laughter',
#  8423: 'nashville',
#  22846: 'bourgeois',
#  19833: '##nat',
#  23074: 'scrolls',
#  6704: 'controversy',
#  18040: 'rosemary',
#  901: '[unused896]',
#  14543: 'sergei',
#  19976: 'fuse',
#  11772: 'chips',
#  3972: 'del',
#  10559: '##lee',
#  14965: 'geometric',
#  5400: '##ara',
#  20959: '##xley',
#  21283: 'narration',
#  18090: 'patton',
#  17144: 'disappears',
#  1260: 'ף',
#  8110: 'filling',
#  18373: 'idle',
#  7090: 'midnight',
#  24894: '##cum',
#  15080: 'granting',
#  29259: 'vidal',
#  15308: 'staging',
#  9904: 'darker',
#  8925: 'bailey',
#  22409: 'repository',
#  12575: 'aloud',
#  24099: 'montenegrin',
#  25472: 'pisa',
#  21863: 'hen',
#  26990: 'babylonian',
#  9516: '##nna',
#  2025: 'not',
#  29632: '##?',
#  26045: 'parasitic',
#  13414: '1792',
#  21449: 'vascular',
#  29664: '##¼',
#  687: '[unused682]',
#  8499: 'unity',
#  29294: 'geek',
#  16178: 'bihar',
#  2547: 'television',
#  770: '[unused765]',
#  7856: '##ona',
#  22995: 'disturb',
#  24361: 'amateurs',
#  13147: 'crept',
#  28060: '##lez',
#  18174: 'shrewsbury',
#  5548: 'montreal',
#  25293: '##hae',
#  3097: 'foreign',
#  17130: '##dam',
#  991: '[unused986]',
#  1662: 'ち',
#  17213: 'forgiveness',
#  28467: 'restrain',
#  10326: 'keen',
#  7272: 'wealthy',
#  4148: 'happen',
#  4206: 'tall',
#  5636: 'ethnic',
#  9344: 'cleaning',
#  27294: 'intersecting',
#  18891: '##avi',
#  23340: 'glands',
#  4393: 'vampire',
#  1757: '亻',
#  17110: '##₀',
#  25344: '##esthesia',
#  30125: '##∗',
#  13011: 'edged',
#  27508: 'straightening',
#  15701: 'shouts',
#  7528: 'implemented',
#  22080: 'rashid',
#  1927: '禾',
#  28319: 'aqua',
#  28505: '##zog',
#  10710: 'ink',
#  4095: '##sh',
#  15283: 'ambush',
#  12151: 'identifying',
#  29681: '##ə',
#  18280: 'depart',
#  19150: '##sable',
#  2654: '28',
#  5214: 'capable',
#  18649: 'chargers',
#  16498: 'capitalism',
#  990: '[unused985]',
#  1244: 'ד',
#  3414: 'zealand',
#  12877: 'elisabeth',
#  19942: 'squared',
#  14280: 'endurance',
#  9274: 'nasa',
#  11005: 'heal',
#  21468: 'thrusting',
#  3426: 'cause',
#  16953: 'algerian',
#  29070: 'groningen',
#  13263: 'stabbed',
#  28229: 'heterosexual',
#  22796: 'archival',
#  19174: 'nanny',
#  28815: 'pigment',
#  10998: 'marching',
#  6112: 'cloud',
#  20: '[unused19]',
#  29703: '##ʑ',
#  21320: 'napier',
#  3393: 'le',
#  18134: 'penguins',
#  25818: 'bae',
#  25412: 'luisa',
#  7137: 'produces',
#  18074: 'waits',
#  24301: '##tracted',
#  14043: 'rivera',
#  13341: 'injection',
#  12466: 'publishes',
#  25210: 'lash',
#  1197: 'т',
#  15756: 'neural',
#  28547: 'programmers',
#  24045: '##nee',
#  14599: 'fortunately',
#  10400: 'bombardment',
#  10916: 'loser',
#  18119: 'centimeters',
#  21398: '##working',
#  24263: 'oliveira',
#  11095: 'allocated',
#  25117: 'peptide',
#  8285: 'auto',
#  19740: 'syed',
#  19960: 'med',
#  20248: 'geo',
#  15870: 'prompting',
#  13651: 'fiba',
#  9719: 'cyprus',
#  13868: 'acquiring',
#  20392: 'coarse',
#  19703: 'probation',
#  17488: 'dal',
#  24084: 'horne',
#  24626: 'hesitantly',
#  24703: '##jm',
#  27195: 'assent',
#  1123: 'ɲ',
#  24692: 'engulfed',
#  27813: '£5',
#  14499: '##usion',
#  11051: 'woodland',
#  19283: 'prevailing',
#  12593: 'negro',
#  4814: '1924',
#  1792: '合',
#  13703: 'woody',
#  17762: 'multiplayer',
#  2759: 'popular',
#  2120: 'national',
#  17258: '##vid',
#  4466: '48',
#  30510: '##ﬁ',
#  3051: '##ley',
#  24622: '306',
#  5164: 'string',
#  24399: 'pistons',
#  28689: '##para',
#  29269: '422',
#  11279: 'sailors',
#  5183: 'ltd',
#  753: '[unused748]',
#  11319: '##ichi',
#  12318: 'treating',
#  5093: 'tennis',
#  4846: 'employed',
#  19737: 'injected',
#  24268: '##aster',
#  1309: 'ی',
#  29262: 'jingle',
#  18389: '##dies',
#  1282: 'س',
#  21992: 'trainers',
#  1708: 'セ',
#  11016: 'contracted',
#  6416: 'missions',
#  6733: 'gates',
#  14904: 'soda',
#  23567: '##tell',
#  27622: 'worsened',
#  22923: '##laya',
#  21847: '##tung',
#  21527: 'conveyed',
#  3554: 'fighting',
#  11765: 'tendency',
#  13856: 'announcing',
#  26144: 'excursion',
#  26413: 'thierry',
#  20299: 'accumulation',
#  5132: 'blues',
#  29801: '##מ',
#  4636: 'fund',
#  13494: 'implications',
#  14759: 'drowning',
#  23304: 'ordeal',
#  9095: 'requirement',
#  27926: 'sonya',
#  26987: 'geraldine',
#  3515: '65',
#  8482: 'montgomery',
#  14166: 'audrey',
#  13001: 'groan',
#  14283: 'prayed',
#  14740: '##shed',
#  15262: 'ada',
#  18486: 'friedman',
#  20341: '60s',
#  25436: 'mathew',
#  27308: 'brothel',
#  8262: 'roland',
#  6954: 'milan',
#  10785: 'precisely',
#  18538: 'acquitted',
#  28663: 'memorabilia',
#  13065: 'drawer',
#  3100: 'okay',
#  26801: '##rries',
#  29825: '##ش',
#  5526: 'ridge',
#  1134: 'ʌ',
#  28863: '##lizer',
#  1737: 'ン',
#  3848: 'victoria',
#  24432: 'amin',
#  6634: 'panic',
#  18252: '##cating',
#  7511: 'conventional',
#  15743: 'naive',
#  19226: 'giro',
#  21266: '##mins',
#  20759: 'ciudad',
#  23350: '##virus',
#  15717: 'skies',
#  21627: 'edouard',
#  3955: '1970s',
#  6834: '##king',
#  15826: 'copied',
#  4142: 'alive',
#  18058: 'delivers',
#  5720: 'talked',
#  27629: '##hony',
#  16112: 'inherent',
#  18978: 'atari',
#  28009: '1738',
#  9218: 'gesture',
#  12369: 'insight',
#  8435: 'ruins',
#  13760: 'erection',
#  23955: '##skie',
#  27161: 'elects',
#  18614: 'wichita',
#  11097: '##boy',
#  24903: 'dew',
#  15556: 'sickness',
#  534: '[unused529]',
#  14475: 'postponed',
#  5325: 'crisis',
#  21545: 'jewellery',
#  9247: '##del',
#  15584: 'registry',
#  10280: '##born',
#  6731: 'suspended',
#  9013: '##ien',
#  9570: 'construct',
#  21166: '##rain',
#  19473: '##bbe',
#  25300: '##mini',
#  351: '[unused346]',
#  5138: 'accept',
#  30426: '##治',
#  3031: 'onto',
#  338: '[unused333]',
#  23722: '##sul',
#  12975: 'barton',
#  14951: 'prophecy',
#  1507: 'ᵢ',
#  8061: 'narrowed',
#  15286: '##tile',
#  5958: 'friday',
#  21895: 'bangor',
#  5540: 'constituency',
#  27644: 'asserting',
#  22766: 'cramped',
#  13440: 'consort',
#  8991: 'gen',
#  2780: 'teams',
#  17500: 'grossed',
#  24418: 'clones',
#  21628: 'tab',
#  9367: 'duration',
#  29436: '##л',
#  17181: 'encoding',
#  21559: '##sam',
#  7514: 'reply',
#  22948: '##relli',
#  28640: '##eza',
#  1364: 'দ',
#  11889: 'discharge',
#  12278: 'meals',
#  22387: 'jerking',
#  3181: 'historic',
#  19008: 'insides',
#  5599: 'letting',
#  ...}

# %%
v[1]
# Out:
# tensor(18237)

# %%
tokken=tokenizer(doc, return_tensors="pt")['input_ids']

# %%
argmax = argmax[col].cpu().tolist()

# %%
argmax
# Out:
# [2,
#  2,
#  1,
#  9,
#  5,
#  2,
#  2,
#  2,
#  8,
#  3,
#  7,
#  3,
#  6,
#  10,
#  8,
#  1,
#  0,
#  4,
#  0,
#  3,
#  0,
#  4,
#  9,
#  2,
#  7,
#  7,
#  2,
#  0,
#  0,
#  0,
#  8,
#  6,
#  7,
#  3]

# %%
# largefiles/TaoFiles/splade/splade/evaluation/eval.py

# %%
import argparse
import json
from splade.evaluation.eval import mrr_k, evaluate


def load_and_evaluate(qrel_file_path, run_file_path, metric,*args, **kwargs):
    with open(qrel_file_path) as reader:
        qrel = json.load(reader)
    with open(run_file_path) as reader:
        run = json.load(reader)
    # for trec, qrel_binary.json should be used for recall etc., qrel.json for NDCG.
    # if qrel.json is used for binary metrics, the binary 'splits' are not correct
    if "TREC" in qrel_file_path:
        assert ("binary" not in qrel_file_path) == (metric == "ndcg" or metric == "ndcg_cut")
    if metric == "mrr_10":
        res = mrr_k(run, qrel, k=10)
        print("MRR@10:", res)
        return {"mrr_10": res}
    else:
        res = evaluate(run, qrel, metric=metric,*args, **kwargs)
        print(metric, "==>", res)
        return res
run="experiments/cocondenser_ensemble_distil/out2/TREC_DL_2019/run.json"
qrels="data/msmarco/TREC_DL_2019/qrel.json"
metric="ndcg_cut"
res=load_and_evaluate(qrels,run,metric,agg=False)
# Out:
# ndcg_cut ==> {'156493': {'ndcg_cut_5': 0.8550077055393716, 'ndcg_cut_10': 0.8347727710785315, 'ndcg_cut_15': 0.8690005115907, 'ndcg_cut_20': 0.8892363940828747, 'ndcg_cut_30': 0.8903459863148391, 'ndcg_cut_100': 0.8456686930864262, 'ndcg_cut_200': 0.8616580574038185, 'ndcg_cut_500': 0.9080776185302061, 'ndcg_cut_1000': 0.9353519759599007}, '1110199': {'ndcg_cut_5': 0.8008157892980455, 'ndcg_cut_10': 0.8559744731298657, 'ndcg_cut_15': 0.8633110478805224, 'ndcg_cut_20': 0.7593214811183402, 'ndcg_cut_30': 0.6812161237801484, 'ndcg_cut_100': 0.7513523120199341, 'ndcg_cut_200': 0.8071607930105618, 'ndcg_cut_500': 0.8173835461142229, 'ndcg_cut_1000': 0.8265029855898373}, '1063750': {'ndcg_cut_5': 0.7345577848667817, 'ndcg_cut_10': 0.839758543431562, 'ndcg_cut_15': 0.8702436132800725, 'ndcg_cut_20': 0.8750719642322907, 'ndcg_cut_30': 0.8590294134716118, 'ndcg_cut_100': 0.6047392488251477, 'ndcg_cut_200': 0.46676931377556363, 'ndcg_cut_500': 0.4990821187824705, 'ndcg_cut_1000': 0.5552268914382369}, '130510': {'ndcg_cut_5': 0.9286712450884907, 'ndcg_cut_10': 0.919578460568148, 'ndcg_cut_15': 0.8945415949179722, 'ndcg_cut_20': 0.8873039816570719, 'ndcg_cut_30': 0.8611845562710531, 'ndcg_cut_100': 0.9388921427598985, 'ndcg_cut_200': 0.9388921427598985, 'ndcg_cut_500': 0.9388921427598985, 'ndcg_cut_1000': 0.9388921427598985}, '489204': {'ndcg_cut_5': 0.3550077055393716, 'ndcg_cut_10': 0.27138809734266756, 'ndcg_cut_15': 0.23581271462991918, 'ndcg_cut_20': 0.2774391923319685, 'ndcg_cut_30': 0.29047566357029914, 'ndcg_cut_100': 0.18586328619131326, 'ndcg_cut_200': 0.22947824829600313, 'ndcg_cut_500': 0.3124088238455828, 'ndcg_cut_1000': 0.402812819551212}, '573724': {'ndcg_cut_5': 0.7100154110787432, 'ndcg_cut_10': 0.6435949318510843, 'ndcg_cut_15': 0.6828905413223075, 'ndcg_cut_20': 0.727465692795367, 'ndcg_cut_30': 0.7918623128617619, 'ndcg_cut_100': 0.7843005858857244, 'ndcg_cut_200': 0.8099398382665872, 'ndcg_cut_500': 0.8315412106672061, 'ndcg_cut_1000': 0.8364833195144845}, '168216': {'ndcg_cut_5': 1.0, 'ndcg_cut_10': 0.9787930706003494, 'ndcg_cut_15': 0.9835609586500214, 'ndcg_cut_20': 0.9749594161190428, 'ndcg_cut_30': 0.9807574227464801, 'ndcg_cut_100': 0.9795873557768153, 'ndcg_cut_200': 0.8782952826471844, 'ndcg_cut_500': 0.8605859459942327, 'ndcg_cut_1000': 0.8876763862667177}, '1133167': {'ndcg_cut_5': 0.7104016925041139, 'ndcg_cut_10': 0.7383393764316539, 'ndcg_cut_15': 0.814890887780786, 'ndcg_cut_20': 0.837980180999013, 'ndcg_cut_30': 0.8765721265439566, 'ndcg_cut_100': 0.9205221728894467, 'ndcg_cut_200': 0.8548355977090021, 'ndcg_cut_500': 0.8795638647697243, 'ndcg_cut_1000': 0.8893642440863058}, '527433': {'ndcg_cut_5': 0.6406165216830382, 'ndcg_cut_10': 0.5416687420249771, 'ndcg_cut_15': 0.5342266859823683, 'ndcg_cut_20': 0.48910785266298346, 'ndcg_cut_30': 0.3931619572891707, 'ndcg_cut_100': 0.41580015096173184, 'ndcg_cut_200': 0.5696807289537751, 'ndcg_cut_500': 0.6584439426202039, 'ndcg_cut_1000': 0.6968058672295585}, '1037798': {'ndcg_cut_5': 0.1992601340685329, 'ndcg_cut_10': 0.1528664175953766, 'ndcg_cut_15': 0.1936957860914163, 'ndcg_cut_20': 0.1936957860914163, 'ndcg_cut_30': 0.1936957860914163, 'ndcg_cut_100': 0.2457336136825558, 'ndcg_cut_200': 0.2593142288473466, 'ndcg_cut_500': 0.2699033159605732, 'ndcg_cut_1000': 0.290471661070332}, '915593': {'ndcg_cut_5': 0.8201054725400893, 'ndcg_cut_10': 0.6862700880267711, 'ndcg_cut_15': 0.5746304208598559, 'ndcg_cut_20': 0.5015730987448686, 'ndcg_cut_30': 0.44863201600630365, 'ndcg_cut_100': 0.38177535862459894, 'ndcg_cut_200': 0.6537188119020251, 'ndcg_cut_500': 0.7831683507459297, 'ndcg_cut_1000': 0.7831683507459297}, '264014': {'ndcg_cut_5': 0.943473299121064, 'ndcg_cut_10': 0.8724279870538272, 'ndcg_cut_15': 0.8708044223311049, 'ndcg_cut_20': 0.858355179976767, 'ndcg_cut_30': 0.9078903381667531, 'ndcg_cut_100': 0.8956037680714932, 'ndcg_cut_200': 0.8276259007348764, 'ndcg_cut_500': 0.885219022465384, 'ndcg_cut_1000': 0.9063082789062165}, '1121402': {'ndcg_cut_5': 1. ...

# %%
# Out:
# {'156493': {'ndcg_cut_5': 0.8550077055393716,
#   'ndcg_cut_10': 0.8347727710785315,
#   'ndcg_cut_15': 0.8690005115907,
#   'ndcg_cut_20': 0.8892363940828747,
#   'ndcg_cut_30': 0.8903459863148391,
#   'ndcg_cut_100': 0.8456686930864262,
#   'ndcg_cut_200': 0.8616580574038185,
#   'ndcg_cut_500': 0.9080776185302061,
#   'ndcg_cut_1000': 0.9353519759599007},
#  '1110199': {'ndcg_cut_5': 0.8008157892980455,
#   'ndcg_cut_10': 0.8559744731298657,
#   'ndcg_cut_15': 0.8633110478805224,
#   'ndcg_cut_20': 0.7593214811183402,
#   'ndcg_cut_30': 0.6812161237801484,
#   'ndcg_cut_100': 0.7513523120199341,
#   'ndcg_cut_200': 0.8071607930105618,
#   'ndcg_cut_500': 0.8173835461142229,
#   'ndcg_cut_1000': 0.8265029855898373},
#  '1063750': {'ndcg_cut_5': 0.7345577848667817,
#   'ndcg_cut_10': 0.839758543431562,
#   'ndcg_cut_15': 0.8702436132800725,
#   'ndcg_cut_20': 0.8750719642322907,
#   'ndcg_cut_30': 0.8590294134716118,
#   'ndcg_cut_100': 0.6047392488251477,
#   'ndcg_cut_200': 0.46676931377556363,
#   'ndcg_cut_500': 0.4990821187824705,
#   'ndcg_cut_1000': 0.5552268914382369},
#  '130510': {'ndcg_cut_5': 0.9286712450884907,
#   'ndcg_cut_10': 0.919578460568148,
#   'ndcg_cut_15': 0.8945415949179722,
#   'ndcg_cut_20': 0.8873039816570719,
#   'ndcg_cut_30': 0.8611845562710531,
#   'ndcg_cut_100': 0.9388921427598985,
#   'ndcg_cut_200': 0.9388921427598985,
#   'ndcg_cut_500': 0.9388921427598985,
#   'ndcg_cut_1000': 0.9388921427598985},
#  '489204': {'ndcg_cut_5': 0.3550077055393716,
#   'ndcg_cut_10': 0.27138809734266756,
#   'ndcg_cut_15': 0.23581271462991918,
#   'ndcg_cut_20': 0.2774391923319685,
#   'ndcg_cut_30': 0.29047566357029914,
#   'ndcg_cut_100': 0.18586328619131326,
#   'ndcg_cut_200': 0.22947824829600313,
#   'ndcg_cut_500': 0.3124088238455828,
#   'ndcg_cut_1000': 0.402812819551212},
#  '573724': {'ndcg_cut_5': 0.7100154110787432,
#   'ndcg_cut_10': 0.6435949318510843,
#   'ndcg_cut_15': 0.6828905413223075,
#   'ndcg_cut_20': 0.727465692795367,
#   'ndcg_cut_30': 0.7918623128617619,
#   'ndcg_cut_100': 0.7843005858857244,
#   'ndcg_cut_200': 0.8099398382665872,
#   'ndcg_cut_500': 0.8315412106672061,
#   'ndcg_cut_1000': 0.8364833195144845},
#  '168216': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 0.9787930706003494,
#   'ndcg_cut_15': 0.9835609586500214,
#   'ndcg_cut_20': 0.9749594161190428,
#   'ndcg_cut_30': 0.9807574227464801,
#   'ndcg_cut_100': 0.9795873557768153,
#   'ndcg_cut_200': 0.8782952826471844,
#   'ndcg_cut_500': 0.8605859459942327,
#   'ndcg_cut_1000': 0.8876763862667177},
#  '1133167': {'ndcg_cut_5': 0.7104016925041139,
#   'ndcg_cut_10': 0.7383393764316539,
#   'ndcg_cut_15': 0.814890887780786,
#   'ndcg_cut_20': 0.837980180999013,
#   'ndcg_cut_30': 0.8765721265439566,
#   'ndcg_cut_100': 0.9205221728894467,
#   'ndcg_cut_200': 0.8548355977090021,
#   'ndcg_cut_500': 0.8795638647697243,
#   'ndcg_cut_1000': 0.8893642440863058},
#  '527433': {'ndcg_cut_5': 0.6406165216830382,
#   'ndcg_cut_10': 0.5416687420249771,
#   'ndcg_cut_15': 0.5342266859823683,
#   'ndcg_cut_20': 0.48910785266298346,
#   'ndcg_cut_30': 0.3931619572891707,
#   'ndcg_cut_100': 0.41580015096173184,
#   'ndcg_cut_200': 0.5696807289537751,
#   'ndcg_cut_500': 0.6584439426202039,
#   'ndcg_cut_1000': 0.6968058672295585},
#  '1037798': {'ndcg_cut_5': 0.1992601340685329,
#   'ndcg_cut_10': 0.1528664175953766,
#   'ndcg_cut_15': 0.1936957860914163,
#   'ndcg_cut_20': 0.1936957860914163,
#   'ndcg_cut_30': 0.1936957860914163,
#   'ndcg_cut_100': 0.2457336136825558,
#   'ndcg_cut_200': 0.2593142288473466,
#   'ndcg_cut_500': 0.2699033159605732,
#   'ndcg_cut_1000': 0.290471661070332},
#  '915593': {'ndcg_cut_5': 0.8201054725400893,
#   'ndcg_cut_10': 0.6862700880267711,
#   'ndcg_cut_15': 0.5746304208598559,
#   'ndcg_cut_20': 0.5015730987448686,
#   'ndcg_cut_30': 0.44863201600630365,
#   'ndcg_cut_100': 0.38177535862459894,
#   'ndcg_cut_200': 0.6537188119020251,
#   'ndcg_cut_500': 0.7831683507459297,
#   'ndcg_cut_1000': 0.7831683507459297},
#  '264014': {'ndcg_cut_5': 0.943473299121064,
#   'ndcg_cut_10': 0.8724279870538272,
#   'ndcg_cut_15': 0.8708044223311049,
#   'ndcg_cut_20': 0.858355179976767,
#   'ndcg_cut_30': 0.9078903381667531,
#   'ndcg_cut_100': 0.8956037680714932,
#   'ndcg_cut_200': 0.8276259007348764,
#   'ndcg_cut_500': 0.885219022465384,
#   'ndcg_cut_1000': 0.9063082789062165},
#  '1121402': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 1.0,
#   'ndcg_cut_15': 0.9781656007375309,
#   'ndcg_cut_20': 0.9486212243035796,
#   'ndcg_cut_30': 0.9176469746561026,
#   'ndcg_cut_100': 0.914209711249215,
#   'ndcg_cut_200': 0.9563527143176138,
#   'ndcg_cut_500': 0.9563527143176138,
#   'ndcg_cut_1000': 0.9563527143176138},
#  '962179': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 1.0,
#   'ndcg_cut_15': 0.8660886590035398,
#   'ndcg_cut_20': 0.7873611989440604,
#   'ndcg_cut_30': 0.8163255713854772,
#   'ndcg_cut_100': 0.9475999004883707,
#   'ndcg_cut_200': 0.9475999004883707,
#   'ndcg_cut_500': 0.9475999004883707,
#   'ndcg_cut_1000': 0.9475999004883707},
#  '1117099': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 1.0,
#   'ndcg_cut_15': 1.0,
#   'ndcg_cut_20': 0.9555516385328002,
#   'ndcg_cut_30': 0.8656972608539064,
#   'ndcg_cut_100': 0.5826408849315572,
#   'ndcg_cut_200': 0.5631913541843083,
#   'ndcg_cut_500': 0.5858516796329917,
#   'ndcg_cut_1000': 0.6154854011927742},
#  '148538': {'ndcg_cut_5': 0.6620782255740881,
#   'ndcg_cut_10': 0.5898800525573265,
#   'ndcg_cut_15': 0.5319618955285828,
#   'ndcg_cut_20': 0.5560748149427273,
#   'ndcg_cut_30': 0.5231423416096171,
#   'ndcg_cut_100': 0.4443499648195221,
#   'ndcg_cut_200': 0.5068962175066908,
#   'ndcg_cut_500': 0.6227666000673093,
#   'ndcg_cut_1000': 0.6651626782318649},
#  '451602': {'ndcg_cut_5': 0.5812069939828565,
#   'ndcg_cut_10': 0.5932499685451033,
#   'ndcg_cut_15': 0.6408950712577293,
#   'ndcg_cut_20': 0.6567610824503498,
#   'ndcg_cut_30': 0.5658156994749981,
#   'ndcg_cut_100': 0.3540565566558504,
#   'ndcg_cut_200': 0.35270305111695144,
#   'ndcg_cut_500': 0.3965541200849145,
#   'ndcg_cut_1000': 0.44408984111027466},
#  '359349': {'ndcg_cut_5': 0.7231933675456026,
#   'ndcg_cut_10': 0.7942386796128393,
#   'ndcg_cut_15': 0.8778026964478685,
#   'ndcg_cut_20': 0.8814100634873105,
#   'ndcg_cut_30': 0.8869141046688213,
#   'ndcg_cut_100': 0.7953838074874152,
#   'ndcg_cut_200': 0.831110438200368,
#   'ndcg_cut_500': 0.8669541144514396,
#   'ndcg_cut_1000': 0.8788400102514959},
#  '1115776': {'ndcg_cut_5': 0.8538265712370683,
#   'ndcg_cut_10': 0.8444054735127555,
#   'ndcg_cut_15': 0.8370548573096059,
#   'ndcg_cut_20': 0.7698015881791597,
#   'ndcg_cut_30': 0.7139488112675643,
#   'ndcg_cut_100': 0.7836866211732673,
#   'ndcg_cut_200': 0.7945828999989007,
#   'ndcg_cut_500': 0.8245222991364862,
#   'ndcg_cut_1000': 0.8245222991364862},
#  '1112341': {'ndcg_cut_5': 0.7738931964842558,
#   'ndcg_cut_10': 0.577612984431169,
#   'ndcg_cut_15': 0.554529016475893,
#   'ndcg_cut_20': 0.472625961271336,
#   'ndcg_cut_30': 0.3861477089287519,
#   'ndcg_cut_100': 0.24896511605319574,
#   'ndcg_cut_200': 0.26740320046321664,
#   'ndcg_cut_500': 0.4509110238926553,
#   'ndcg_cut_1000': 0.6401480252170648},
#  '131843': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 0.6489315753318465,
#   'ndcg_cut_15': 0.5915135357773097,
#   'ndcg_cut_20': 0.5862452326309087,
#   'ndcg_cut_30': 0.5305279395824551,
#   'ndcg_cut_100': 0.5300180854799367,
#   'ndcg_cut_200': 0.5300180854799367,
#   'ndcg_cut_500': 0.5300180854799367,
#   'ndcg_cut_1000': 0.5300180854799367},
#  '104861': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 1.0,
#   'ndcg_cut_15': 1.0,
#   'ndcg_cut_20': 1.0,
#   'ndcg_cut_30': 1.0,
#   'ndcg_cut_100': 0.8342204681388299,
#   'ndcg_cut_200': 0.8242196130979096,
#   'ndcg_cut_500': 0.9063754179950674,
#   'ndcg_cut_1000': 0.9107997070788767},
#  '833860': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 0.977915258848537,
#   'ndcg_cut_15': 0.9380190523688617,
#   'ndcg_cut_20': 0.9344691000417857,
#   'ndcg_cut_30': 0.9635584811043615,
#   'ndcg_cut_100': 0.8555018494399753,
#   'ndcg_cut_200': 0.8835585268779301,
#   'ndcg_cut_500': 0.9154558647198812,
#   'ndcg_cut_1000': 0.9336157859496546},
#  '207786': {'ndcg_cut_5': 0.819972692711383,
#   'ndcg_cut_10': 0.6391480283952147,
#   'ndcg_cut_15': 0.6449063393355534,
#   'ndcg_cut_20': 0.6794750860726473,
#   'ndcg_cut_30': 0.7480877508437748,
#   'ndcg_cut_100': 0.8166366106951272,
#   'ndcg_cut_200': 0.8166366106951272,
#   'ndcg_cut_500': 0.8166366106951272,
#   'ndcg_cut_1000': 0.8166366106951272},
#  '1114819': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 0.8829771917772821,
#   'ndcg_cut_15': 0.8492815790841236,
#   'ndcg_cut_20': 0.8503686443046375,
#   'ndcg_cut_30': 0.9267230103601043,
#   'ndcg_cut_100': 0.8978185248198982,
#   'ndcg_cut_200': 0.7582796488381456,
#   'ndcg_cut_500': 0.7932744687788564,
#   'ndcg_cut_1000': 0.8437295671076694},
#  '183378': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 1.0,
#   'ndcg_cut_15': 0.9244528212954666,
#   'ndcg_cut_20': 0.8694883475901878,
#   'ndcg_cut_30': 0.8297596207292989,
#   'ndcg_cut_100': 0.6459375770752009,
#   'ndcg_cut_200': 0.5412489533109023,
#   'ndcg_cut_500': 0.6023084698253595,
#   'ndcg_cut_1000': 0.6676991579081673},
#  '1106007': {'ndcg_cut_5': 0.4109557550857762,
#   'ndcg_cut_10': 0.6264732818269876,
#   'ndcg_cut_15': 0.7073536349668217,
#   'ndcg_cut_20': 0.6661824318259157,
#   'ndcg_cut_30': 0.5949959897816663,
#   'ndcg_cut_100': 0.5145045006655204,
#   'ndcg_cut_200': 0.5572475709280381,
#   'ndcg_cut_500': 0.599303243221863,
#   'ndcg_cut_1000': 0.6276924054283273},
#  '1124210': {'ndcg_cut_5': 0.39883521630455965,
#   'ndcg_cut_10': 0.3959824221672385,
#   'ndcg_cut_15': 0.3265329559236741,
#   'ndcg_cut_20': 0.2822474383820748,
#   'ndcg_cut_30': 0.24679341328766613,
#   'ndcg_cut_100': 0.15716326315728674,
#   'ndcg_cut_200': 0.19712266094378417,
#   'ndcg_cut_500': 0.263522159975471,
#   'ndcg_cut_1000': 0.34647651008704156},
#  '490595': {'ndcg_cut_5': 0.49012176092865256,
#   'ndcg_cut_10': 0.4917459781954087,
#   'ndcg_cut_15': 0.6364128735715715,
#   'ndcg_cut_20': 0.685975879294353,
#   'ndcg_cut_30': 0.7424384075212568,
#   'ndcg_cut_100': 0.7645130256549884,
#   'ndcg_cut_200': 0.8104815101517924,
#   'ndcg_cut_500': 0.8207829523037462,
#   'ndcg_cut_1000': 0.8207829523037462},
#  '1103812': {'ndcg_cut_5': 0.8981633226998278,
#   'ndcg_cut_10': 0.7542467729976889,
#   'ndcg_cut_15': 0.6602670357310522,
#   'ndcg_cut_20': 0.6889380586471885,
#   'ndcg_cut_30': 0.6246526054792546,
#   'ndcg_cut_100': 0.7002467392090037,
#   'ndcg_cut_200': 0.7002467392090037,
#   'ndcg_cut_500': 0.7296357095699768,
#   'ndcg_cut_1000': 0.7296357095699768},
#  '87181': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 0.9652843890316114,
#   'ndcg_cut_15': 0.883315473187779,
#   'ndcg_cut_20': 0.8858232659172512,
#   'ndcg_cut_30': 0.7976609291600919,
#   'ndcg_cut_100': 0.7883597379830536,
#   'ndcg_cut_200': 0.8839914381171662,
#   'ndcg_cut_500': 0.904685577995164,
#   'ndcg_cut_1000': 0.9160451258180409},
#  '443396': {'ndcg_cut_5': 0.5087403079104241,
#   'ndcg_cut_10': 0.3301376494471202,
#   'ndcg_cut_15': 0.2559138274179071,
#   'ndcg_cut_20': 0.22565570174221045,
#   'ndcg_cut_30': 0.21187296231019126,
#   'ndcg_cut_100': 0.15332605329324353,
#   'ndcg_cut_200': 0.17673452153023542,
#   'ndcg_cut_500': 0.21472758563194896,
#   'ndcg_cut_1000': 0.2173489684126302},
#  '1121709': {'ndcg_cut_5': 0.7183368720136839,
#   'ndcg_cut_10': 0.7874426987228027,
#   'ndcg_cut_15': 0.8399619828972398,
#   'ndcg_cut_20': 0.9058604448483989,
#   'ndcg_cut_30': 0.9058604448483989,
#   'ndcg_cut_100': 0.9058604448483989,
#   'ndcg_cut_200': 0.9058604448483989,
#   'ndcg_cut_500': 0.9058604448483989,
#   'ndcg_cut_1000': 0.9058604448483989},
#  '87452': {'ndcg_cut_5': 0.5742421908816505,
#   'ndcg_cut_10': 0.4913448133999967,
#   'ndcg_cut_15': 0.5012317313427894,
#   'ndcg_cut_20': 0.46340514261500304,
#   'ndcg_cut_30': 0.46091092960177343,
#   'ndcg_cut_100': 0.46986382110652375,
#   'ndcg_cut_200': 0.5018511390451699,
#   'ndcg_cut_500': 0.5205487331001484,
#   'ndcg_cut_1000': 0.5468294605750629},
#  '855410': {'ndcg_cut_5': 0.9082209380838205,
#   'ndcg_cut_10': 0.9792557322123484,
#   'ndcg_cut_15': 0.9792557322123484,
#   'ndcg_cut_20': 0.9792557322123484,
#   'ndcg_cut_30': 0.9792557322123484,
#   'ndcg_cut_100': 0.9792557322123484,
#   'ndcg_cut_200': 0.9792557322123484,
#   'ndcg_cut_500': 0.9792557322123484,
#   'ndcg_cut_1000': 0.9792557322123484},
#  '1114646': {'ndcg_cut_5': 1.0,
#   'ndcg_cut_10': 0.8137867468854345,
#   'ndcg_cut_15': 0.8171863012837611,
#   'ndcg_cut_20': 0.8158981463427011,
#   'ndcg_cut_30': 0.8268090954226454,
#   'ndcg_cut_100': 0.7700075477041675,
#   'ndcg_cut_200': 0.8205733245050796,
#   'ndcg_cut_500': 0.8490956316867048,
#   'ndcg_cut_1000': 0.8539701736548022},
#  '19335': {'ndcg_cut_5': 0.6152825049032233,
#   'ndcg_cut_10': 0.544828290841365,
#   'ndcg_cut_15': 0.5302045667698605,
#   'ndcg_cut_20': 0.5183021685914683,
#   'ndcg_cut_30': 0.5335477125828253,
#   'ndcg_cut_100': 0.5998163615745911,
#   'ndcg_cut_200': 0.6215212704114317,
#   'ndcg_cut_500': 0.6477126409867421,
#   'ndcg_cut_1000': 0.6960557864494421},
#  '47923': {'ndcg_cut_5': 0.38202278328090217,
#   'ndcg_cut_10': 0.547720786297593,
#   'ndcg_cut_15': 0.641985713945256,
#   'ndcg_cut_20': 0.6908132047189924,
#   'ndcg_cut_30': 0.6722182009311924,
#   'ndcg_cut_100': 0.5379806252220213,
#   'ndcg_cut_200': 0.5706760225206055,
#   'ndcg_cut_500': 0.6761671749362894,
#   'ndcg_cut_1000': 0.7391127361064607},
#  '405717': {'ndcg_cut_5': 0.6261806449294969,
#   'ndcg_cut_10': 0.7233918906007402,
#   'ndcg_cut_15': 0.7902121827376842,
#   'ndcg_cut_20': 0.7680044731963895,
#   'ndcg_cut_30': 0.742728152685233,
#   'ndcg_cut_100': 0.7743394496738417,
#   'ndcg_cut_200': 0.8453057359831849,
#   'ndcg_cut_500': 0.8453057359831849,
#   'ndcg_cut_1000': 0.8453057359831849},
#  '182539': {'ndcg_cut_5': 0.5724961472303142,
#   'ndcg_cut_10': 0.6596773213356888,
#   'ndcg_cut_15': 0.7243338258205255,
#   'ndcg_cut_20': 0.7510684964440626,
#   'ndcg_cut_30': 0.7885488084375176,
#   'ndcg_cut_100': 0.7928779448069575,
#   'ndcg_cut_200': 0.800209031962865,
#   'ndcg_cut_500': 0.806454291659419,
#   'ndcg_cut_1000': 0.8120265319821002},
#  '1113437': {'ndcg_cut_5': 0.5186921112829956,
#   'ndcg_cut_10': 0.4844914014356644,
#   'ndcg_cut_15': 0.5085633394169972,
#   'ndcg_cut_20': 0.46230473058026983,
#   'ndcg_cut_30': 0.439086932174625,
#   'ndcg_cut_100': 0.47791760798974287,
#   'ndcg_cut_200': 0.5968849436812026,
#   'ndcg_cut_500': 0.6970696180476009,
#   'ndcg_cut_1000': 0.7091211809398459},
#  '1129237': {'ndcg_cut_5': 0.6843515475204854,
#   'ndcg_cut_10': 0.708582411379182,
#   'ndcg_cut_15': 0.7250424684658887,
#   'ndcg_cut_20': 0.7733235125333677,
#   'ndcg_cut_30': 0.8024179007700742,
#   'ndcg_cut_100': 0.8725030982027271,
#   'ndcg_cut_200': 0.8792555936859229,
#   'ndcg_cut_500': 0.8792555936859229,
#   'ndcg_cut_1000': 0.8792555936859229},
#  '146187': {'ndcg_cut_5': 0.917452487864839,
#   'ndcg_cut_10': 0.8357491797450901,
#   'ndcg_cut_15': 0.8097842945560035,
#   'ndcg_cut_20': 0.7906108465749585,
#   'ndcg_cut_30': 0.7997516644489996,
#   'ndcg_cut_100': 0.8440653271844708,
#   'ndcg_cut_200': 0.8550845155267628,
#   'ndcg_cut_500': 0.8650690800308131,
#   'ndcg_cut_1000': 0.8731808391305738}}
